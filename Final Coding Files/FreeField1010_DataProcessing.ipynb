# %%
import os
import librosa
import numpy as np
import pandas as pd
import soundfile as sf
import librosa.display
# !pip install pydub
from pydub import AudioSegment
from scipy.io import wavfile
import IPython.display as ipd
from matplotlib import pyplot as plt
from sklearn.decomposition import FastICA
from scipy.signal import butter, lfilter

import warnings
warnings.filterwarnings('ignore')

# %%
# Downloading Freefield1010 Dataset Metadata file
# !wget https://ndownloader.figshare.com/files/6035814
# Out:
# --2021-11-25 14:35:11--  https://ndownloader.figshare.com/files/6035814
# Resolving ndownloader.figshare.com (ndownloader.figshare.com)... 52.16.102.173, 54.217.124.219, 2a05:d018:1f4:d000:b283:27aa:b939:8ed4, ...
# Connecting to ndownloader.figshare.com (ndownloader.figshare.com)|52.16.102.173|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://s3-eu-west-1.amazonaws.com/pfigshare-u-files/6035814/ff1010bird_metadata.csv?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIAIYCQYOYV5JSSROOA/20211125/eu-west-1/s3/aws4_request&X-Amz-Date=20211125T143512Z&X-Amz-Expires=10&X-Amz-SignedHeaders=host&X-Amz-Signature=9e906b8945979b442d57d192f609aca68de4e5e09518d14d4964ab1066f96d2a [following]
# ...

# %%
# Downloading Freefield1010 Dataset
# !wget https://archive.org/download/ff1010bird/ff1010bird_wav.zip
# Out:
# --2021-11-25 14:35:24--  https://archive.org/download/ff1010bird/ff1010bird_wav.zip
# Resolving archive.org (archive.org)... 207.241.224.2
# Connecting to archive.org (archive.org)|207.241.224.2|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://ia601202.us.archive.org/35/items/ff1010bird/ff1010bird_wav.zip [following]
# --2021-11-25 14:35:24--  https://ia601202.us.archive.org/35/items/ff1010bird/ff1010bird_wav.zip
# Resolving ia601202.us.archive.org (ia601202.us.archive.org)... 207.241.227.132
# Connecting to ia601202.us.archive.org (ia601202.us.archive.org)|207.241.227.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5772437544 (5.4G) [application/zip]
# Saving to: ‘ff1010bird_wav.zip’
#
# ff1010bird_wav.zip  100%[===================>]   5.38G  1.82MB/s    in 43m 52s
#
# 2021-11-25 15:19:16 (2.09 MB/s) - ‘ff1010bird_wav.zip’ saved [5772437544/5772437544]

# %%
# Extracting Zip file of Freefield1010 Dataset

import zipfile

with zipfile.ZipFile('/content/drive/MyDrive/ff1010bird_wav.zip', 'r') as zip_ref:
  zip_ref.extractall('/content/drive/MyDrive/Final Project - Fall 2021/freefield1010')

# %%
# Fetching Freefield1010 Dataset metadata csv file

freefield_labels = pd.read_csv("/content/drive/MyDrive/Final Project - Fall 2021/freefield1010/ff1010bird_metadata.csv")
print("Total audios : ",len(freefield_labels))
# Out:
# total audios :  7690

# %%
# Making chunks of 5 seconds for Freefield1010 Dataset

base_path = "/content/drive/MyDrive/Final Project - Fall 2021/freefield1010/wav/"

# Variables to store chunk path and labels
chunkPath = np.zeros(len(freefield_labels)*2, dtype = 'U256')
chunkLabels = np.zeros(len(freefield_labels)*2)

curChunk = 0
for i in range(len(x)):
  audio_name = str(freefield_labels['itemid'][i])
  label = freefield_labels['hasbird'][i]

  # Loading particular audio
  x1, sr1 = librosa.load(base_path+audio_name+".wav", sr = 44100)

  # Making 5 seconds chunks of loaded audio
  for j in range(2):
    t1 = j * 5 * 44100
    chunk = x1[t1:t1+(44100*5)]

    if(chunk.shape[0] == 220500):  
      # saving audio
      filename = '/content/drive/MyDrive/Final Project - Fall 2021/Freefield Chunk Data/'+audio_name+'_'+str(j)+'.wav'
      sf.write(filename, chunk, 44100)

      # Storing chunk path and label
      chunkPath[curChunk] = filename
      chunkLabels[curChunk] = label
    else:
      errorFileId.append(id)
      print("File Name: " + trainData["filename"][id])
    
    curChunk = curChunk + 1

# %%
# Making CSV file to store chunk path and labels of Freefield1010 Dataset
temp = np.vstack([chunkPath,chunkLabels])
dataframe = temp.T
path_labels = pd.DataFrame(dataframe, columns=['FFAudioPath','FFClassLabels'])
path_labels.to_csv('/content/drive/MyDrive/Final Project - Fall 2021/freefield_path_labels.csv', index=False)
print(path_labels)
# Out:
#                                              FFAudioPath FFClassLabels
# 0      /content/drive/MyDrive/Final Project - Fall 20...           0.0
# 1      /content/drive/MyDrive/Final Project - Fall 20...           0.0
# 2      /content/drive/MyDrive/Final Project - Fall 20...           0.0
# 3      /content/drive/MyDrive/Final Project - Fall 20...           0.0
# 4      /content/drive/MyDrive/Final Project - Fall 20...           0.0
# ...                                                  ...           ...
# 15375  /content/drive/MyDrive/Final Project - Fall 20...           1.0
# 15376  /content/drive/MyDrive/Final Project - Fall 20...           1.0
# 15377  /content/drive/MyDrive/Final Project - Fall 20...           1.0
# 15378  /content/drive/MyDrive/Final Project - Fall 20...           0.0
# 15379  /content/drive/MyDrive/Final Project - Fall 20...           0.0
#
# [15380 rows x 2 columns]

# %%
# Fetching CSV file of chunk path and labels for Freefield1010 Dataset
freefield_labels = pd.read_csv("/content/drive/MyDrive/Final Project - Fall 2021/freefield_path_labels.csv")
freefield_labels.head()
# Out:
#                                          FFAudioPath  FFClassLabels
# 0  /content/drive/MyDrive/Final Project - Fall 20...            0.0
# 1  /content/drive/MyDrive/Final Project - Fall 20...            0.0
# 2  /content/drive/MyDrive/Final Project - Fall 20...            0.0
# 3  /content/drive/MyDrive/Final Project - Fall 20...            0.0
# 4  /content/drive/MyDrive/Final Project - Fall 20...            0.0

# %% [markdown]
# **Visual Feature Extraction - FreeField1010 Dataset**

# %%
errorFileId = []

# Variable to store generated mel-spectrograms
vis_feat = np.zeros((len(freefield_labels)//2, 128,431), dtype = float)

# Total number of chunks to be processed for one iteration
noChunks = len(freefield_labels)//2

sr = 44100  
n_fft=1024
hop_length=512

# Generating mel-spectrograms
for i in range(2):
  curChunk = 0
  for id in range(i*noChunks, (i+1)*noChunks):
    if (id%100 == 0 or id==(len(freefield_labels)-1)):
      print("Processed Audios : ", id)

    try:
      # Loading particular audio
      x1, sr1 = librosa.load(freefield_labels['FFAudioPath'][id], sr = sr)

      # Generating mel-spectrogram
      mel = librosa.feature.melspectrogram(x1, 44100, n_mels=128, n_fft=1024, hop_length=512, fmin=20, fmax=16000)
      
      # Transforming to mel scale or log based
      mel_scale = librosa.power_to_db(abs(mel)) 

      # Storing generated mel-spectrogram
      vis_feat[curChunk] = mel_scale

    except Exception as e:
      print(e)
      errorFileId.append(id)
      print("File Path: " + freefield_labels['FFAudioPath'][id])

    curChunk = curChunk + 1

  # Saving into file
  a1 = str(i*noChunks)
  a2 = str((i+1)*noChunks)
  filename = "vis_feat_"+a1+"_"+a2+".npy"
  np.save('/content/drive/MyDrive/Final Project - Fall 2021/FF Visual Feat/'+filename, vis_feat)
  print("Saved : ", a1, " to ", a2)
# Out:
# Processed Audios :  0
# Processed Audios :  100
# Processed Audios :  200
# Processed Audios :  300
# Processed Audios :  400
# Processed Audios :  500
# Processed Audios :  600
# Processed Audios :  700
# Processed Audios :  800
# Processed Audios :  900
# Processed Audios :  1000
# Processed Audios :  1100
# Processed Audios :  1200
# Processed Audios :  1300
# Processed Audios :  1400
# Processed Audios :  1500
# Processed Audios :  1600
# Processed Audios :  1700
# Processed Audios :  1800
# Processed Audios :  1900
# Processed Audios :  2000
# Processed Audios :  2100
# Processed Audios :  2200
# Processed Audios :  2300
# Processed Audios :  2400
# Processed Audios :  2500
# Processed Audios :  2600
# Processed Audios :  2700
# Processed Audios :  2800
# Processed Audios :  2900
# Processed Audios :  3000
# Processed Audios :  3100
# Processed Audios :  3200
# Processed Audios :  3300
# Processed Audios :  3400
# Processed Audios :  3500
# Processed Audios :  3600
# ...

# %% [markdown]
# **Converting Visual Features into RGB Channels**

# %%
# Loading CSV file of chunk path and labels of Freefield1010 Dataset
pathLabels = pd.read_csv("/content/drive/MyDrive/Final Project - Fall 2021/freefield_path_labels.csv")
pathLabels.head()
# Out:
#                                          FFAudioPath  FFClassLabels
# 0  /content/drive/MyDrive/Final Project - Fall 20...            0.0
# 1  /content/drive/MyDrive/Final Project - Fall 20...            0.0
# 2  /content/drive/MyDrive/Final Project - Fall 20...            0.0
# 3  /content/drive/MyDrive/Final Project - Fall 20...            0.0
# 4  /content/drive/MyDrive/Final Project - Fall 20...            0.0

# %%
labels = np.array(pathLabels['FFClassLabels'])
print(labels.shape)
# Out:
# (15380,)

# %%
# Converting 1st chunk file into RGB channel which contains 0-7690 samples

# Laoding 1st chunk file
freefieldData = np.load("/content/drive/MyDrive/Final Project - Fall 2021/FF Visual Feat 2/vis_feat_0_7690.npy")

# Variables to store RGB converted features and labels
freefieldDataRGB = np.zeros((len(freefieldData)//2,128,431,3), dtype='uint8')
chunkLabels = np.zeros(len(freefieldData)//2)

# Dividing further into two files
for j in range(2):
  curChunk = 0
  for i in range(j*len(freefieldDataRGB), (j+1)*len(freefieldDataRGB)):
    # Converting mel-spectrograms into RGB
    rgbData0 = np.stack([freefieldData[i], freefieldData[i], freefieldData[i]], axis=-1)
    mean = rgbData0.mean()
    std = rgbData0.std()
    Xstd = (rgbData0 - mean) / (std + 1e-6)
    _min, _max = Xstd.min(), Xstd.max()
    norm_max = _max
    norm_min = _min
    if (_max - _min) > 1e-6:
        # Scale to [0, 255]
        V = Xstd
        V[V < norm_min] = norm_min
        V[V > norm_max] = norm_max
        V = 255 * (V - norm_min) / (norm_max - norm_min)
        freefieldDataRGB[curChunk] = V
    else:
        # Just zero
        V = np.zeros_like(Xstd, dtype=np.uint8)
        freefieldDataRGB[curChunk] = V
    curChunk = curChunk + 1
  
  chunkLabels = labels[j*len(freefieldDataRGB):(j+1)*len(freefieldDataRGB)]

  # Saving into files
  filename = "vis_feat_"+str(j)+".npy"
  filename2 = "labels_"+str(j)+".npy"
  np.save('/content/drive/MyDrive/Final Project - Fall 2021/FF Visual Feat 2 RGB/'+filename, freefieldDataRGB)
  np.save('/content/drive/MyDrive/Final Project - Fall 2021/FF Visual Feat 2 RGB/'+filename2, chunkLabels)
  print("Saved :"+filename+" and "+filename2)
# Out:
# Saved :vis_feat_0.npy and labels_0.npy
# Saved :vis_feat_1.npy and labels_1.npy

# %%
# Converting 2nd chunk file into RGB channel which contains 7690-15380 samples

# Laoding 2nd chunk file
freefieldData = np.load("/content/drive/MyDrive/Final Project - Fall 2021/FF Visual Feat 2/vis_feat_7690_15380.npy")

# Variables to store RGB converted features and labels
freefieldDataRGB = np.zeros((len(freefieldData)//2,128,431,3), dtype='uint8')
chunkLabels = np.zeros(len(freefieldData)//2)

pad = 7690

# Dividing further into two files
for j in range(2):
  curChunk = 0
  for i in range(j*len(freefieldDataRGB), (j+1)*len(freefieldDataRGB)):
    # Converting mel-spectrograms into RGB
    rgbData0 = np.stack([freefieldData[i], freefieldData[i], freefieldData[i]], axis=-1)
    mean = rgbData0.mean()
    std = rgbData0.std()
    Xstd = (rgbData0 - mean) / (std + 1e-6)
    _min, _max = Xstd.min(), Xstd.max()
    norm_max = _max
    norm_min = _min
    if (_max - _min) > 1e-6:
        # Scale to [0, 255]
        V = Xstd
        V[V < norm_min] = norm_min
        V[V > norm_max] = norm_max
        V = 255 * (V - norm_min) / (norm_max - norm_min)
        freefieldDataRGB[curChunk] = V
    else:
        # Just zero
        V = np.zeros_like(Xstd, dtype=np.uint8)
        freefieldDataRGB[curChunk] = V
    curChunk = curChunk + 1
  
  chunkLabels = labels[(j*len(freefieldDataRGB))+pad:((j+1)*len(freefieldDataRGB))+pad]

  # Saving into files
  filename = "vis_feat_"+str(j+2)+".npy"
  filename2 = "labels_"+str(j+2)+".npy"
  np.save('/content/drive/MyDrive/Final Project - Fall 2021/FF Visual Feat 2 RGB/'+filename, freefieldDataRGB)
  np.save('/content/drive/MyDrive/Final Project - Fall 2021/FF Visual Feat 2 RGB/'+filename2, chunkLabels)
  print("Saved :"+filename+" and "+filename2)
# Out:
# Saved :vis_feat_2.npy and labels_2.npy
# Saved :vis_feat_3.npy and labels_3.npy

# %% [markdown]
# **Statistical Features Extraction - Freefield1010 Dataset**

# %%
errorFileId = []

# Taking 500 chunks at a time
noChunks = 500
sr = 44100  

# Stores Chunk Path and Labels
chunkLabels = np.zeros(noChunks, dtype = 'U256')
chunkPath = np.zeros(noChunks, dtype = 'U1024')

# Variables to store statistical features
mfcc_final = np.zeros((noChunks, 20))
zcr_final = np.zeros((noChunks))
cs_final = np.zeros((noChunks, 12))
rolloff_final = np.zeros((noChunks))
RMSE_final = np.zeros((noChunks))
centroids_final = np.zeros((noChunks))
contrast_final = np.zeros((noChunks, 7))
bandwidth_final = np.zeros((noChunks))
tonnetz_final = np.zeros((noChunks, 6))
flatness_final = np.zeros((noChunks))
cqt_final = np.zeros((noChunks, 12))
cens_final = np.zeros((noChunks, 12))

sr = 44100

print("Chunks of 500 :")

# Extracting statistical features by taking 500 chunks at a time
for i in range(0, len(freefield_labels["FFAudioPath"])//noChunks):

  curChunk = 0
  # Taking 500 chunks
  for id in range(i*noChunks,(i+1)*noChunks):
    if (id%100 == 0 or id==(len(freefield_labels)-1)):
      print("Processed Audios : ", id)

    try:
      # Loading chunk audio
      chunkData, sr1 = librosa.load(freefield_labels["FFAudioPath"][id], sr = sr)

      # Storing chunk audio path and label
      chunkLabels[curChunk] = freefield_labels["FFClassLabels"][id]
      chunkPath[curChunk] = freefield_labels["FFAudioPath"][id]

      # Zero Crossing Rate Feature
      zero_crossings = librosa.feature.zero_crossing_rate(chunkData)
      zcr_final[curChunk] = np.mean(zero_crossings)

      # MFCC Feature
      mfccs = librosa.feature.mfcc(chunkData, sr)
      mfcc_final[curChunk] = np.mean(mfccs, axis=1)

      # Chroma Shift Feature
      chroma_shift = librosa.feature.chroma_stft(chunkData, sr)
      cs_final[curChunk] = np.mean(chroma_shift, axis=1)

      # Spectral Rolloff Feature
      rolloff = librosa.feature.spectral_rolloff(chunkData, sr)
      rolloff_final[curChunk] = np.mean(rolloff)

      # RMSE Feature
      RMSE = librosa.feature.rms(chunkData)
      RMSE_final[curChunk] = np.mean(RMSE)

      # Spectral Centroid Feature
      spectral_centroids = librosa.feature.spectral_centroid(chunkData, sr)
      centroids_final[curChunk] = np.mean(spectral_centroids)

      # Spectral Contrast Feature
      spectral_contrast = librosa.feature.spectral_contrast(chunkData, sr)
      contrast_final[curChunk] = np.mean(spectral_contrast, axis=1)

      # Spectral Bandwidth Feature
      spectral_bandwidth = librosa.feature.spectral_bandwidth(chunkData, sr)
      bandwidth_final[curChunk] = np.mean(spectral_bandwidth)

      # Tonnetz Feature
      tonnetz = librosa.feature.tonnetz(chunkData, sr)
      tonnetz_final[curChunk] = np.mean(tonnetz, axis=1)

      # Spectral Flatness Feature
      spectral_flatness = librosa.feature.spectral_flatness(chunkData)
      flatness_final[curChunk] = np.mean(spectral_flatness)

      # Chroma Constant-Q Chromogram Feature
      chroma_cqt = librosa.feature.chroma_cqt(chunkData, sr)
      cqt_final[curChunk] = np.mean(chroma_cqt, axis=1)

      # Chroma CENS (Chroma Energy Normalized) Feature
      chroma_cens = librosa.feature.chroma_cens(chunkData, sr)
      cens_final[curChunk] = np.mean(chroma_cens, axis=1)

    except Exception as e:
      print(e)
      errorFileId.append(id)
      print("File Path: " + freefield_labels["FFAudioPath"][id])

    curChunk = curChunk + 1

  # Saving into file
  temp = np.vstack([chunkPath,chunkLabels])
  dataframe = temp.T
  path_labels = pd.DataFrame(dataframe, columns=['FFAudioPath','FFClassLabels'])

  # Assigning column-wise data
  path_labels = path_labels.assign(ZeroCrossingsRate=zcr_final, SpectralRolloff=rolloff_final,
                      RMSEnergy=RMSE_final, SpectralCentroids=centroids_final, 
                      SpectralBandwidth=bandwidth_final, MFCC0 = mfcc_final[:, 0], 
                      MFCC1 = mfcc_final[:, 1], MFCC2 = mfcc_final[:, 2], MFCC3 = mfcc_final[:, 3],
                      MFCC4 = mfcc_final[:, 4], MFCC5 = mfcc_final[:, 5], MFCC6 = mfcc_final[:, 6],
                      MFCC7 = mfcc_final[:, 7], MFCC8 = mfcc_final[:, 8], MFCC9 = mfcc_final[:, 9],
                      MFCC10 = mfcc_final[:, 10], MFCC11 = mfcc_final[:, 11], MFCC12 = mfcc_final[:, 12],
                      MFCC13 = mfcc_final[:, 13], MFCC14 = mfcc_final[:, 14], MFCC15 = mfcc_final[:, 15],
                      MFCC16 = mfcc_final[:, 16], MFCC17 = mfcc_final[:, 17], MFCC18 = mfcc_final[:, 18],
                      MFCC19 = mfcc_final[:, 19], 
                      CS0 = cs_final[:, 0], CS1 = cs_final[:, 1], CS2 = cs_final[:, 2], CS3 = cs_final[:, 3], CS4 = cs_final[:, 4], 
                      CS5 = cs_final[:, 5], CS6 = cs_final[:, 6], CS7 = cs_final[:, 7], CS8 = cs_final[:, 8], CS9 = cs_final[:, 9], 
                      CS10 = cs_final[:, 10], CS11 = cs_final[:, 11], 
                      Ccqt0 = cqt_final[:, 0], Ccqt1 = cqt_final[:, 1], Ccqt2 = cqt_final[:, 2], Ccqt3 = cqt_final[:, 3], 
                      Ccqt4 = cqt_final[:, 4], Ccqt5 = cqt_final[:, 5], Ccqt6 = cqt_final[:, 6], Ccqt7 = cqt_final[:, 7], 
                      Ccqt8 = cqt_final[:, 8], Ccqt9 = cqt_final[:, 9], Ccqt10 = cqt_final[:, 10], Ccqt11 = cqt_final[:, 11], 
                      Ccens0 = cens_final[:, 0], Ccens1 = cens_final[:, 1], Ccens2 = cens_final[:, 2], Ccens3 = cens_final[:, 3], 
                      Ccens4 = cens_final[:, 4], Ccens5 = cens_final[:, 5], Ccens6 = cens_final[:, 6], Ccens7 = cens_final[:, 7], 
                      Ccens8 = cens_final[:, 8], Ccens9 = cens_final[:, 9], Ccens10 = cens_final[:, 10], Ccens11 = cens_final[:, 11], 
                      SC0 = contrast_final[:, 0], SC1 = contrast_final[:, 1], SC2 = contrast_final[:, 2], 
                      SC3 = contrast_final[:, 3], SC4 = contrast_final[:, 4], SC5 = contrast_final[:, 5], SC6 = contrast_final[:, 6], 
                      TZ0 = tonnetz_final[:, 0], TZ1 = tonnetz_final[:, 1], TZ2 = tonnetz_final[:, 2], 
                      TZ3 = tonnetz_final[:, 3], TZ4 = tonnetz_final[:, 4], TZ5 = tonnetz_final[:, 5])
  
  path_labels.to_csv('/content/drive/MyDrive/Final Project - Fall 2021/FF_stat_feat.csv', mode = 'a', header = not os.path.exists('/content/drive/MyDrive/Final Project - Fall 2021/FF_stat_feat.csv'), index=False)
  print("Saved : ", i*noChunks, " to ", (i+1)*noChunks)
# Out:
# Chunks of 500 :
# Processed Audios :  11500
# Processed Audios :  11600
# Processed Audios :  11700
# Processed Audios :  11800
# Processed Audios :  11900
# Saved :  11500  to  12000
# Processed Audios :  12000
# Processed Audios :  12100
# Processed Audios :  12200
# Processed Audios :  12300
# Processed Audios :  12400
# Saved :  12000  to  12500
# Processed Audios :  12500
# Processed Audios :  12600
# Processed Audios :  12700
# Processed Audios :  12800
# Processed Audios :  12900
# Saved :  12500  to  13000
# Processed Audios :  13000
# Processed Audios :  13100
# Processed Audios :  13200
# Processed Audios :  13300
# Processed Audios :  13400
# Saved :  13000  to  13500
# Processed Audios :  13500
# Processed Audios :  13600
# Processed Audios :  13700
# Processed Audios :  13800
# Processed Audios :  13900
# Saved :  13500  to  14000
# Processed Audios :  14000
# Processed Audios :  14100
# Processed Audios :  14200
# Processed Audios :  14300
# Processed Audios :  14400
# ...

# %%
# Same thing but for last remaining 380 chunk audios
curChunk = 0
for id in range(15000, len(freefield_labels)):
  if (id%100 == 0 or id==(len(freefield_labels)-1)):
    print("Processed Audios : ", id)

  try:
    # Loading chunk audio
    chunkData, sr1 = librosa.load(freefield_labels["FFAudioPath"][id], sr = sr)
    
    # Storing chunk audio path and label
    chunkLabels[curChunk] = freefield_labels["FFClassLabels"][id]
    chunkPath[curChunk] = freefield_labels["FFAudioPath"][id]

    # Zero Crossing Rate Feature
    zero_crossings = librosa.feature.zero_crossing_rate(chunkData)
    zcr_final[curChunk] = np.mean(zero_crossings)

    # MFCC Feature
    mfccs = librosa.feature.mfcc(chunkData, sr)
    mfcc_final[curChunk] = np.mean(mfccs, axis=1)

    # Chroma Shift Feature
    chroma_shift = librosa.feature.chroma_stft(chunkData, sr)
    cs_final[curChunk] = np.mean(chroma_shift, axis=1)

    # Spectral Rolloff Feature
    rolloff = librosa.feature.spectral_rolloff(chunkData, sr)
    rolloff_final[curChunk] = np.mean(rolloff)

    # RMSE Feature
    RMSE = librosa.feature.rms(chunkData)
    RMSE_final[curChunk] = np.mean(RMSE)

    # Spectral Centroid Feature
    spectral_centroids = librosa.feature.spectral_centroid(chunkData, sr)
    centroids_final[curChunk] = np.mean(spectral_centroids)

    # Spectral Contrast Feature
    spectral_contrast = librosa.feature.spectral_contrast(chunkData, sr)
    contrast_final[curChunk] = np.mean(spectral_contrast, axis=1)

    # Spectral Bandwidth Feature
    spectral_bandwidth = librosa.feature.spectral_bandwidth(chunkData, sr)
    bandwidth_final[curChunk] = np.mean(spectral_bandwidth)

    # Tonnetz Feature
    tonnetz = librosa.feature.tonnetz(chunkData, sr)
    tonnetz_final[curChunk] = np.mean(tonnetz, axis=1)

    # Spectral Flatness Feature
    spectral_flatness = librosa.feature.spectral_flatness(chunkData)
    flatness_final[curChunk] = np.mean(spectral_flatness)

    # Chroma Constant-Q Chromogram Feature
    chroma_cqt = librosa.feature.chroma_cqt(chunkData, sr)
    cqt_final[curChunk] = np.mean(chroma_cqt, axis=1)

    # Chroma CENS (Chroma Energy Normalized) Feature
    chroma_cens = librosa.feature.chroma_cens(chunkData, sr)
    cens_final[curChunk] = np.mean(chroma_cens, axis=1)

  except Exception as e:
    print(e)
    errorFileId.append(id)
    print("File Path: " + freefield_labels["FFAudioPath"][id])

  curChunk = curChunk + 1

# Saving into file
temp = np.vstack([chunkPath, chunkLabels])
dataframe = temp.T
path_labels = pd.DataFrame(dataframe, columns=['FFAudioPath', 'FFClassLabels'])

# Assigning column-wise data
path_labels = path_labels.assign(ZeroCrossingsRate=zcr_final, SpectralRolloff=rolloff_final,
                    RMSEnergy=RMSE_final, SpectralCentroids=centroids_final, 
                    SpectralBandwidth=bandwidth_final, MFCC0 = mfcc_final[:, 0], 
                    MFCC1 = mfcc_final[:, 1], MFCC2 = mfcc_final[:, 2], MFCC3 = mfcc_final[:, 3],
                    MFCC4 = mfcc_final[:, 4], MFCC5 = mfcc_final[:, 5], MFCC6 = mfcc_final[:, 6],
                    MFCC7 = mfcc_final[:, 7], MFCC8 = mfcc_final[:, 8], MFCC9 = mfcc_final[:, 9],
                    MFCC10 = mfcc_final[:, 10], MFCC11 = mfcc_final[:, 11], MFCC12 = mfcc_final[:, 12],
                    MFCC13 = mfcc_final[:, 13], MFCC14 = mfcc_final[:, 14], MFCC15 = mfcc_final[:, 15],
                    MFCC16 = mfcc_final[:, 16], MFCC17 = mfcc_final[:, 17], MFCC18 = mfcc_final[:, 18],
                    MFCC19 = mfcc_final[:, 19], 
                    CS0 = cs_final[:, 0], CS1 = cs_final[:, 1], CS2 = cs_final[:, 2], CS3 = cs_final[:, 3], CS4 = cs_final[:, 4], 
                    CS5 = cs_final[:, 5], CS6 = cs_final[:, 6], CS7 = cs_final[:, 7], CS8 = cs_final[:, 8], CS9 = cs_final[:, 9], 
                    CS10 = cs_final[:, 10], CS11 = cs_final[:, 11], 
                    Ccqt0 = cqt_final[:, 0], Ccqt1 = cqt_final[:, 1], Ccqt2 = cqt_final[:, 2], Ccqt3 = cqt_final[:, 3], 
                    Ccqt4 = cqt_final[:, 4], Ccqt5 = cqt_final[:, 5], Ccqt6 = cqt_final[:, 6], Ccqt7 = cqt_final[:, 7], 
                    Ccqt8 = cqt_final[:, 8], Ccqt9 = cqt_final[:, 9], Ccqt10 = cqt_final[:, 10], Ccqt11 = cqt_final[:, 11], 
                    Ccens0 = cens_final[:, 0], Ccens1 = cens_final[:, 1], Ccens2 = cens_final[:, 2], Ccens3 = cens_final[:, 3], 
                    Ccens4 = cens_final[:, 4], Ccens5 = cens_final[:, 5], Ccens6 = cens_final[:, 6], Ccens7 = cens_final[:, 7], 
                    Ccens8 = cens_final[:, 8], Ccens9 = cens_final[:, 9], Ccens10 = cens_final[:, 10], Ccens11 = cens_final[:, 11], 
                    SC0 = contrast_final[:, 0], SC1 = contrast_final[:, 1], SC2 = contrast_final[:, 2], 
                    SC3 = contrast_final[:, 3], SC4 = contrast_final[:, 4], SC5 = contrast_final[:, 5], SC6 = contrast_final[:, 6], 
                    TZ0 = tonnetz_final[:, 0], TZ1 = tonnetz_final[:, 1], TZ2 = tonnetz_final[:, 2], 
                    TZ3 = tonnetz_final[:, 3], TZ4 = tonnetz_final[:, 4], TZ5 = tonnetz_final[:, 5])

path_labels.to_csv('/content/drive/MyDrive/Final Project - Fall 2021/FF_stat_feat.csv', mode = 'a', header = not os.path.exists('/content/drive/MyDrive/Final Project - Fall 2021/FF_stat_feat.csv'), index=False)
# Out:
# Processed Audios :  15000
# Processed Audios :  15100
# Processed Audios :  15200
# Processed Audios :  15300
# Processed Audios :  15379

# %%
# Fetching CSV file of Statistical Features
freefield_stat= pd.read_csv("/content/drive/MyDrive/Final Project - Fall 2021/FF_stat_feat.csv")
freefield_stat.head()
# Out:
#                                          FFAudioPath  FFClassLabels  \
# 0  /content/drive/MyDrive/Final Project - Fall 20...            0.0
# 1  /content/drive/MyDrive/Final Project - Fall 20...            0.0
# 2  /content/drive/MyDrive/Final Project - Fall 20...            0.0
# 3  /content/drive/MyDrive/Final Project - Fall 20...            0.0
# 4  /content/drive/MyDrive/Final Project - Fall 20...            0.0
#
#    ZeroCrossingsRate  SpectralRolloff  RMSEnergy  SpectralCentroids  \
# 0           0.061878      2747.556781   0.127419        1714.413719
# 1           0.055904      2597.873541   0.096333        1588.230318
# 2           0.021343      3217.889900   0.068515        1563.491378
# 3           0.027383      5216.331025   0.042080        2208.089095
# 4           0.202284     11644.566710   0.036253        5574.748999
#
#    SpectralBandwidth       MFCC0       MFCC1      MFCC2  ...        SC3  \
# ...
