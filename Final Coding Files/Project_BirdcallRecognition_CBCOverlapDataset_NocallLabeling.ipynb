# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from keras.applications.vgg16 import preprocess_input
from keras.models import load_model

# %%
# Function for rounding the labels
def RoundFun(labels):

  temp = np.zeros(len(labels))
  
  for i in range(len(labels)):
    if(labels[i] >= 0.5):
      temp[i] = 1
    else:
      temp[i] = 0
  return temp

# %%
# Loading VGG16, Custom CNN and MLP (ANN) model, which are trained on FreeField1010 Dataset
model_vgg16 = load_model("/content/drive/MyDrive/Colab Notebooks/Fall 2021/Final Project/DCNN Models/FF DCNN CV/ff_vis_VGG16_CV1.h5")
model_cust = load_model("/content/drive/MyDrive/Colab Notebooks/Fall 2021/Final Project/DCNN Models/FF DCNN CV/ff_vis_Cust_CV1.h5")
model_stat = load_model("/content/drive/MyDrive/Colab Notebooks/Fall 2021/Final Project/DCNN Models/FF DCNN CV/ff_stat_CV1.h5")

# Applying Standard Scaling on the statistical features
scaler = StandardScaler()
stat_data = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Fall 2021/Final Project/Final_OverlapData_StatFeatures.csv")
ch_stat_data = stat_data.loc[:, 'ZeroCrossingsRate':'MFCC19']
ch_stat_data = scaler.fit_transform(ch_stat_data)

del stat_data

# %%
# Predicting labels of CBC2020 Dataset for Nocall Filtering 
VGGCustStat = np.zeros(5000)
VGGCust = np.zeros(5000)
CustStat = np.zeros(5000)

for i in range(0, 77):
  data_filename = "vis_feat_"+str(i)+".npy"
  
  # Loading Visual Features
  vis_data = np.load("/content/drive/MyDrive/Colab Notebooks/Fall 2021/Final Project/Visual Features_abs_Overlap_RGB/Data/"+data_filename)

  # Predicting labels using trained MLP(ANN), VGG16, and Custom CNN model
  stat_pred = model_stat.predict(ch_stat_data[i*5000:(i+1)*5000])
  vgg_pred = model_vgg16.predict(vis_data)
  cust_pred = model_cust.predict(vis_data)

  if(i == 76):
    vgg_pred = vgg_pred[0:3135]
    cust_pred = cust_pred[0:3135]
    stat_pred = stat_pred[0:3135]

  # Ensembling VGG16 + Custom CNN + MLP(ANN - Statistical Features)
  pred_labels = (vgg_pred + cust_pred + stat_pred)/3
  pred_labels_round = RoundFun(pred_labels)

  # Ensembling VGG16 + Custom CNN
  pred_labels2 = (vgg_pred + cust_pred)/2
  pred_labels_round2 = RoundFun(pred_labels2)

  # Ensembling Custom CNN + MLP(ANN - Statistical Features)
  pred_labels3 = (RoundFun(cust_pred) + RoundFun(stat_pred))/2
  pred_labels_round3 = RoundFun(pred_labels3)

  # Storing ensembled outputs
  if(i == 0):
    VGGCustStat = pred_labels_round
    VGGCust = pred_labels_round2
    CustStat = pred_labels_round3
  else:
    VGGCustStat = np.append(VGGCustStat, pred_labels_round)
    VGGCust = np.append(VGGCust, pred_labels_round2)
    CustStat = np.append(CustStat, pred_labels_round3)

  print("Done : "+data_filename)
# Out:
# Done : vis_feat_44.npy
# Done : vis_feat_45.npy
# Done : vis_feat_46.npy
# Done : vis_feat_47.npy
# Done : vis_feat_48.npy
# Done : vis_feat_49.npy
# Done : vis_feat_50.npy
# Done : vis_feat_51.npy
# Done : vis_feat_52.npy
# Done : vis_feat_53.npy
# Done : vis_feat_54.npy

# %%
i = 77
data_filename = "vis_feat_"+str(i)+".npy"

# Loading Visual Features
vis_data = np.load("/content/drive/MyDrive/Colab Notebooks/Fall 2021/Final Project/Visual Features_abs_Overlap_RGB/Data/"+data_filename)

# Predicting labels using trained MLP(ANN), VGG16, and Custom CNN model
stat_pred = model_stat.predict(ch_stat_data[383135:])
vgg_pred = model_vgg16.predict(vis_data)
cust_pred = model_cust.predict(vis_data)

# Ensembling VGG16 + Custom CNN + MLP(ANN - Statistical Features)
pred_labels = (vgg_pred + cust_pred + stat_pred)/3
pred_labels_round = RoundFun(pred_labels)

# Ensembling VGG16 + Custom CNN
pred_labels2 = (vgg_pred + cust_pred)/2
pred_labels_round2 = RoundFun(pred_labels2)

# Ensembling Custom CNN + MLP(ANN - Statistical Features)
pred_labels3 = (RoundFun(cust_pred) + RoundFun(stat_pred))/2
pred_labels_round3 = RoundFun(pred_labels3)

# Storing ensembled outputs
VGGCustStat = pred_labels_round
VGGCust = pred_labels_round2
CustStat = pred_labels_round3

print("Done : "+data_filename)
# Out:
# Done : vis_feat_77.npy

# %%
# Saving Ensemble outputs into numpy file
np.save("/content/drive/MyDrive/Colab Notebooks/Fall 2021/Final Project/Visual Features_abs_Overlap_RGB/VGGCustStat8.npy", VGGCustStat)
np.save("/content/drive/MyDrive/Colab Notebooks/Fall 2021/Final Project/Visual Features_abs_Overlap_RGB/VGGCust8.npy", VGGCust)
np.save("/content/drive/MyDrive/Colab Notebooks/Fall 2021/Final Project/Visual Features_abs_Overlap_RGB/CustStat8.npy", CustStat)

# %%
# Batch 0-11:
# VGGCustStat: 8127 | 46873
# VGGCust:     5211 | 49789
# CustStat:    5861 | 49139

# Batch 11-22:
# VGGCustStat: 9876 | 45124
# VGGCust:     6751 | 48249
# CustStat:    7422 | 47578

# Batch 22-33:
# VGGCustStat: 9238 | 45762
# VGGCust:     6061 | 48939
# CustStat:    6790 | 48210

# Batch 33-44:
# VGGCustStat: 9635 | 45365
# VGGCust:     6977 | 48023
# CustStat:    7239 | 47761

# Batch 44-55:
# VGGCustStat: 9791 | 45209
# VGGCust:     6625 | 48375
# CustStat:    7036 | 47964
 
# Batch 55-66:
# VGGCustStat: 8628 | 46372
# VGGCust:     5860 | 49140
# CustStat:    6006 | 48994

# Batch 66-77:
# VGGCustStat: 7143 | 45992
# VGGCust:     4951 | 48184
# CustStat:    5003 | 48132

# Batch 78:
# VGGCustStat: 1376 | 5267
# VGGCust:     879  | 5764
# CustStat:    1114 | 5529

# %% [markdown]
# Converting binary labels to string

# %%
# Loading all ensembled labels files of three different ensemble apporaches
VGGCustStat = np.concatenate((np.load('/content/drive/MyDrive/Colab Notebooks/Fall 2021/Final Project/Visual Features_abs_Overlap_RGB/VGGCustStat1.npy'), 
                        np.load('/content/drive/MyDrive/Colab Notebooks/Fall 2021/Final Project/Visual Features_abs_Overlap_RGB/VGGCustStat2.npy'),
                        np.load('/content/drive/MyDrive/Colab Notebooks/Fall 2021/Final Project/Visual Features_abs_Overlap_RGB/VGGCustStat3.npy'),
                        np.load('/content/drive/MyDrive/Colab Notebooks/Fall 2021/Final Project/Visual Features_abs_Overlap_RGB/VGGCustStat4.npy'),
                        np.load('/content/drive/MyDrive/Colab Notebooks/Fall 2021/Final Project/Visual Features_abs_Overlap_RGB/VGGCustStat5.npy'),
                        np.load('/content/drive/MyDrive/Colab Notebooks/Fall 2021/Final Project/Visual Features_abs_Overlap_RGB/VGGCustStat6.npy'),
                        np.load('/content/drive/MyDrive/Colab Notebooks/Fall 2021/Final Project/Visual Features_abs_Overlap_RGB/VGGCustStat7.npy'),
                        np.load('/content/drive/MyDrive/Colab Notebooks/Fall 2021/Final Project/Visual Features_abs_Overlap_RGB/VGGCustStat8.npy')))

VGGCust = np.concatenate((np.load('/content/drive/MyDrive/Colab Notebooks/Fall 2021/Final Project/Visual Features_abs_Overlap_RGB/VGGCust1.npy'), 
                    np.load('/content/drive/MyDrive/Colab Notebooks/Fall 2021/Final Project/Visual Features_abs_Overlap_RGB/VGGCust2.npy'),
                    np.load('/content/drive/MyDrive/Colab Notebooks/Fall 2021/Final Project/Visual Features_abs_Overlap_RGB/VGGCust3.npy'),
                    np.load('/content/drive/MyDrive/Colab Notebooks/Fall 2021/Final Project/Visual Features_abs_Overlap_RGB/VGGCust4.npy'),
                    np.load('/content/drive/MyDrive/Colab Notebooks/Fall 2021/Final Project/Visual Features_abs_Overlap_RGB/VGGCust5.npy'),
                    np.load('/content/drive/MyDrive/Colab Notebooks/Fall 2021/Final Project/Visual Features_abs_Overlap_RGB/VGGCust6.npy'),
                    np.load('/content/drive/MyDrive/Colab Notebooks/Fall 2021/Final Project/Visual Features_abs_Overlap_RGB/VGGCust7.npy'),
                    np.load('/content/drive/MyDrive/Colab Notebooks/Fall 2021/Final Project/Visual Features_abs_Overlap_RGB/VGGCust8.npy')))

CustStat = np.concatenate((np.load('/content/drive/MyDrive/Colab Notebooks/Fall 2021/Final Project/Visual Features_abs_Overlap_RGB/CustStat1.npy'), 
                     np.load('/content/drive/MyDrive/Colab Notebooks/Fall 2021/Final Project/Visual Features_abs_Overlap_RGB/CustStat2.npy'),
                     np.load('/content/drive/MyDrive/Colab Notebooks/Fall 2021/Final Project/Visual Features_abs_Overlap_RGB/CustStat3.npy'),
                     np.load('/content/drive/MyDrive/Colab Notebooks/Fall 2021/Final Project/Visual Features_abs_Overlap_RGB/CustStat4.npy'),
                     np.load('/content/drive/MyDrive/Colab Notebooks/Fall 2021/Final Project/Visual Features_abs_Overlap_RGB/CustStat5.npy'),
                     np.load('/content/drive/MyDrive/Colab Notebooks/Fall 2021/Final Project/Visual Features_abs_Overlap_RGB/CustStat6.npy'),
                     np.load('/content/drive/MyDrive/Colab Notebooks/Fall 2021/Final Project/Visual Features_abs_Overlap_RGB/CustStat7.npy'),
                     np.load('/content/drive/MyDrive/Colab Notebooks/Fall 2021/Final Project/Visual Features_abs_Overlap_RGB/CustStat8.npy')))

# Loading CSV file with audio path, original labels and statistical features
stat_data = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Fall 2021/Final Project/Final_OverlapData_StatFeatures.csv")

print(VGGCustStat.shape)
print(VGGCust.shape)
print(CustStat.shape)
print(stat_data.shape)
# Out:
# (389778,)
# (389778,)
# (389778,)
# (389778, 76)

# %%
VGGCustStatL = np.zeros(len(VGGCustStat), dtype = 'U32')
VGGCustL = np.zeros(len(VGGCust), dtype = 'U32')
CustStatL = np.zeros(len(CustStat), dtype = 'U32')

# Labeling class 0 to Nocall
for i in range(len(VGGCustStat)):
  if(VGGCustStat[i] == 0):
    VGGCustStatL[i] = "Nocall"
  else:
    VGGCustStatL[i] = stat_data.iloc[i,0]

for i in range(len(VGGCust)):
  if(VGGCust[i] == 0):
    VGGCustL[i] = "Nocall"
  else:
    VGGCustL[i] = stat_data.iloc[i,0]

for i in range(len(CustStat)):
  if(CustStat[i] == 0):
    CustStatL[i] = "Nocall"
  else:
    CustStatL[i] = stat_data.iloc[i,0]

# %%
# Adding those predicted labels into 3 separate columns
new_data = stat_data
new_data = new_data.assign(VGGCustStat = VGGCustStatL, VGGCust = VGGCustL, CustStat = CustStatL)
print(new_data.loc[:, 'VGGCustStat':'CustStat'])
# Out:
#        VGGCustStat VGGCust CustStat
# 0           aldfly  aldfly   aldfly
# 1           aldfly  aldfly   aldfly
# 2           aldfly  aldfly   aldfly
# 3           aldfly  aldfly   aldfly
# 4           aldfly  aldfly   aldfly
# ...            ...     ...      ...
# 389773      yetvir  yetvir   yetvir
# 389774      yetvir  yetvir   yetvir
# 389775      Nocall  Nocall   Nocall
# 389776      yetvir  yetvir   yetvir
# 389777      yetvir  yetvir   yetvir
#
# [389778 rows x 3 columns]

# %%
# Saving new CSV file with audio path, original labels, statistical features and predicted labels
new_data.to_csv('/content/drive/MyDrive/Colab Notebooks/Fall 2021/Final Project/Final_OverlapData_StatFeatures_Nocall_Labels.csv', index=False)

# %% [markdown]
# **Code to separate Nocall Data**

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import LabelEncoder 

stat_data = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Fall 2021/Final Project/Final_OverlapData_StatFeatures_Nocall_Labels.csv")

class_labels = stat_data.iloc[:, 76]

# Onehot Encoding of labels
# integer encode
label_encoder = LabelEncoder()
integer_encoded = label_encoder.fit_transform(class_labels)

# binary encode
onehot_encoder = OneHotEncoder(sparse=False)
integer_encoded = integer_encoded.reshape(len(integer_encoded), 1)
onehot_labels = onehot_encoder.fit_transform(integer_encoded)

# %%
for j in range(0, 75):
  # Laoding visual features
  data = np.load("/content/drive/MyDrive/Colab Notebooks/Fall 2021/Final Project/Visual Features_abs_Overlap_RGB/Data/vis_feat_"+str(j)+".npy")

  labels = stat_data.iloc[j*5000:(j+1)*5000, 76]
  labels_onehot = onehot_labels[j*5000:(j+1)*5000, 1:] 

  arr_size = len(labels) - labels.value_counts()["Nocall"]
  new_data = np.zeros((arr_size, 128, 431, 3), dtype='uint8')
  new_labels = np.zeros((arr_size, 264), dtype='uint8')
  arr_labels = np.asarray(labels)

  # Filtering out data which has "Nocall" label
  cnt = 0
  for i in range(len(arr_labels)):
    if(arr_labels[i] != "Nocall"):
      new_data[cnt] = data[i]
      new_labels[cnt] = labels_onehot[i]
      cnt = cnt + 1
  
  print("File {} : {}".format(j, new_data.shape))
  
  # Saving filterd data and labels into files
  np.save("/content/drive/MyDrive/Colab Notebooks/Fall 2021/Final Project/Visual Features_abs_Overlap_RGB/Filtered Data/vis_feat_"+str(j)+".npy",new_data)
  np.save("/content/drive/MyDrive/Colab Notebooks/Fall 2021/Final Project/Visual Features_abs_Overlap_RGB/Filtered Labels/vis_labels_"+str(j)+".npy",new_labels)

  del data
  del new_data
# Out:
# File 0 : (4495, 128, 431, 3)
# File 1 : (4445, 128, 431, 3)
# File 2 : (4404, 128, 431, 3)
# File 3 : (3809, 128, 431, 3)
# File 4 : (4387, 128, 431, 3)
# File 5 : (3738, 128, 431, 3)
# File 6 : (4144, 128, 431, 3)
# File 7 : (4209, 128, 431, 3)
# File 8 : (4186, 128, 431, 3)
# File 9 : (4618, 128, 431, 3)
# File 10 : (4438, 128, 431, 3)
# File 11 : (2816, 128, 431, 3)
# File 12 : (4258, 128, 431, 3)
# File 13 : (3967, 128, 431, 3)
# File 14 : (3861, 128, 431, 3)
# File 15 : (4781, 128, 431, 3)
# File 16 : (4590, 128, 431, 3)
# File 17 : (3969, 128, 431, 3)
# File 18 : (3835, 128, 431, 3)
# File 19 : (4349, 128, 431, 3)
# File 20 : (4555, 128, 431, 3)
# File 21 : (4143, 128, 431, 3)
# File 22 : (3822, 128, 431, 3)
# File 23 : (3691, 128, 431, 3)
# File 24 : (3975, 128, 431, 3)
# File 25 : (4045, 128, 431, 3)
# File 26 : (4149, 128, 431, 3)
# File 27 : (4449, 128, 431, 3)
# File 28 : (4572, 128, 431, 3)
# File 29 : (4362, 128, 431, 3)
# File 30 : (4301, 128, 431, 3)
# File 31 : (4213, 128, 431, 3)
# File 32 : (4183, 128, 431, 3)
# File 33 : (3713, 128, 431, 3)
# File 34 : (3070, 128, 431, 3)
# File 35 : (3803, 128, 431, 3)
# File 36 : (4132, 128, 431, 3)
# File 37 : (4672, 128, 431, 3)
# File 38 : (4257, 128, 431, 3)
# File 39 : (4691, 128, 431, 3)
# File 40 : (4323, 128, 431, 3)
# File 41 : (4224, 128, 431, 3)
# File 42 : (4191, 128, 431, 3)
# File 43 : (4289, 128, 431, 3)
# File 44 : (4265, 128, 431, 3)
# File 45 : (4171, 128, 431, 3)
# File 46 : (3471, 128, 431, 3)
# File 47 : (4045, 128, 431, 3)
# File 48 : (4381, 128, 431, 3)
# File 49 : (4611, 128, 431, 3)
# File 50 : (3947, 128, 431, 3)
# File 51 : (4125, 128, 431, 3)
# File 52 : (4146, 128, 431, 3)
# File 53 : (3643, 128, 431, 3)
# File 54 : (4404, 128, 431, 3)
# File 55 : (4427, 128, 431, 3)
# File 56 : (4273, 128, 431, 3)
# File 57 : (4427, 128, 431, 3)
# File 58 : (4082, 128, 431, 3)
# File 59 : (4194, 128, 431, 3)
# File 60 : (3956, 128, 431, 3)
# File 61 : (4027, 128, 431, 3)
# File 62 : (4560, 128, 431, 3)
# File 63 : (4095, 128, 431, 3)
# File 64 : (4042, 128, 431, 3)
# File 65 : (4289, 128, 431, 3)
# File 66 : (4076, 128, 431, 3)
# File 67 : (4378, 128, 431, 3)
# File 68 : (4306, 128, 431, 3)
# File 69 : (4682, 128, 431, 3)
# File 70 : (4590, 128, 431, 3)
# File 71 : (4731, 128, 431, 3)
# File 72 : (4268, 128, 431, 3)
# File 73 : (4109, 128, 431, 3)
# File 74 : (3966, 128, 431, 3)

# %%
j = 77
# Laoding visual features
data = np.load("/content/drive/MyDrive/Colab Notebooks/Fall 2021/Final Project/Visual Features_abs_Overlap_RGB/Data/vis_feat_"+str(j)+".npy")

labels = stat_data.iloc[383135:, 76]
labels_onehot = onehot_labels[383135:, 1:] 

arr_size = len(labels) - labels.value_counts()["Nocall"]
new_data = np.zeros((arr_size, 128, 431, 3), dtype='uint8')
new_labels = np.zeros((arr_size, 264), dtype='uint8')
arr_labels = np.asarray(labels)

# Filtering out data which has "Nocall" label
cnt = 0
for i in range(len(arr_labels)):
  if(arr_labels[i] != "Nocall"):
    new_data[cnt] = data[i]
    new_labels[cnt] = labels_onehot[i]
    cnt = cnt + 1

print("File {} : {}".format(j, new_data.shape))

# Saving filterd data and labels into files
np.save("/content/drive/MyDrive/Colab Notebooks/Fall 2021/Final Project/Visual Features_abs_Overlap_RGB/Filtered Data/vis_feat_"+str(j)+".npy",new_data)
np.save("/content/drive/MyDrive/Colab Notebooks/Fall 2021/Final Project/Visual Features_abs_Overlap_RGB/Filtered Labels/vis_labels_"+str(j)+".npy",new_labels)

del data
del new_data
# Out:
# File 77 : (5267, 128, 431, 3)

# %% [markdown]
# **Make Batches of 64**

# %%
#Function for saving data and labels into batches of 64
def saveData(temp_data, temp_labels, cnt):
  for i  in range(len(temp_data)//64):
    start = i*64
    end = (i+1)*64
    cnt = cnt + 1
    print("Batch saved : " ,cnt)

    # Saving data and labels into numpy files
    np.save("/content/drive/MyDrive/Colab Notebooks/Fall 2021/Final Project/Visual Features_abs_Overlap_RGB/Batch Data 64/Data/vis_feat_"+str(cnt)+".npy",temp_data[start:end,])
    np.save("/content/drive/MyDrive/Colab Notebooks/Fall 2021/Final Project/Visual Features_abs_Overlap_RGB/Batch Data 64/Labels/vis_labels_"+str(cnt)+".npy",temp_labels[start:end,])
  return cnt

# %%
cnt = 0 
left_data = np.zeros((0, 128, 431, 3), dtype = 'uint8')
left_labels = np.zeros((0, 264), dtype = 'uint8')

for i in range(78):
  # Loading visual features and labels
  data = np.load("/content/drive/MyDrive/Colab Notebooks/Fall 2021/Final Project/Visual Features_abs_Overlap_RGB/Filtered Data/vis_feat_"+str(i)+".npy")
  labels = np.load("/content/drive/MyDrive/Colab Notebooks/Fall 2021/Final Project/Visual Features_abs_Overlap_RGB/Filtered Labels/vis_labels_"+str(i)+".npy")

  # Making batches of 64
  if(len(left_data) != 0):
    new_data = np.concatenate((left_data, data), axis = 0)
    new_labels = np.concatenate((left_labels, labels), axis = 0)
    cnt  = saveData(new_data, new_labels, cnt)
    if(len(new_data)%64 == 0):
      left_data = np.zeros((0, 128, 431, 3), dtype = 'uint8') 
      left_labels = np.zeros((0, 264), dtype = 'uint8')
    else:  
      left_data = new_data[-(len(new_data)%64):,] 
      left_labels = new_labels[-(len(new_labels)%64):,]
    print("\nleft_data : ", left_data.shape)
  else:
    cnt  = saveData(data, labels, cnt)
    left_data = np.zeros((len(data)%64, 128, 431, 3), dtype = 'uint8')
    left_labels = np.zeros((len(labels)%64, 264), dtype = 'uint8')
    left_data = data[-(len(left_data)):,] 
    left_labels = labels[-(len(left_data)):,] 
    print("\nleft_data : ", left_data.shape)
# Out:
# Streaming output truncated to the last 5000 lines.
# Batch saved :  244
# Batch saved :  245
# Batch saved :  246
# Batch saved :  247
# Batch saved :  248
# Batch saved :  249
# Batch saved :  250
# Batch saved :  251
# Batch saved :  252
# Batch saved :  253
# Batch saved :  254
# Batch saved :  255
# Batch saved :  256
# Batch saved :  257
# Batch saved :  258
# Batch saved :  259
# Batch saved :  260
# Batch saved :  261
# Batch saved :  262
# Batch saved :  263
# Batch saved :  264
# Batch saved :  265
# Batch saved :  266
# Batch saved :  267
# Batch saved :  268
#
# left_data :  (1, 128, 431, 3)
# Batch saved :  269
# Batch saved :  270
# Batch saved :  271
# Batch saved :  272
# Batch saved :  273
# Batch saved :  274
# Batch saved :  275
# Batch saved :  276
# Batch saved :  277
# Batch saved :  278
# Batch saved :  279
# Batch saved :  280
# Batch saved :  281
# Batch saved :  282
# Batch saved :  283
# Batch saved :  284
# Batch saved :  285
# Batch saved :  286
# Batch saved :  287
# Batch saved :  288
# Batch saved :  289
# Batch saved :  290
# Batch saved :  291
# Batch saved :  292
# Batch saved :  293
# Batch saved :  294
# Batch saved :  295
# Batch saved :  296
# Batch saved :  297
# Batch saved :  298
# Batch saved :  299
# Batch saved :  300
# Batch saved :  301
# Batch saved :  302
# Batch saved :  303
# Batch saved :  304
# Batch saved :  305
# Batch saved :  306
# Batch saved :  307
# Batch saved :  308
# Batch saved :  309
# Batch saved :  310
# Batch saved :  311
# Batch saved :  312
# Batch saved :  313
# Batch saved :  314
# Batch saved :  315
# Batch saved :  316
# Batch saved :  317
# Batch saved :  318
# Batch saved :  319
# Batch saved :  320
# Batch saved :  321
# Batch saved :  322
# Batch saved :  323
# Batch saved :  324
# Batch saved :  325
# Batch saved :  326
# Batch saved :  327
# Batch saved :  328
# Batch saved :  329
# Batch saved :  330
# Batch saved :  331
# Batch saved :  332
# Batch saved :  333
# Batch saved :  334
# Batch saved :  335
# Batch saved :  336
#
# left_data :  (36, 128, 431, 3)
# Batch saved :  337
# Batch saved :  338
# Batch saved :  339
# Batch saved :  340
# Batch saved :  341
# Batch saved :  342
# Batch saved :  343
# Batch saved :  344
# Batch saved :  345
# Batch saved :  346
# Batch saved :  347
# Batch saved :  348
# Batch saved :  349
# Batch saved :  350
# Batch saved :  351
# Batch saved :  352
# Batch saved :  353
# Batch saved :  354
# Batch saved :  355
# Batch saved :  356
# Batch saved :  357
# Batch saved :  358
# Batch saved :  359
# Batch saved :  360
# Batch saved :  361
# Batch saved :  362
# Batch saved :  363
# Batch saved :  364
# Batch saved :  365
# Batch saved :  366
# Batch saved :  367
# Batch saved :  368
# Batch saved :  369
# Batch saved :  370
# Batch saved :  371
# Batch saved :  372
# Batch saved :  373
# Batch saved :  374
# Batch saved :  375
# Batch saved :  376
# Batch saved :  377
# Batch saved :  378
# Batch saved :  379
# Batch saved :  380
# Batch saved :  381
# Batch saved :  382
# Batch saved :  383
# Batch saved :  384
# Batch saved :  385
# Batch saved :  386
# Batch saved :  387
# Batch saved :  388
# Batch saved :  389
# Batch saved :  390
# Batch saved :  391
# Batch saved :  392
# Batch saved :  393
# Batch saved :  394
#
# left_data :  (62, 128, 431, 3)
# Batch saved :  395
# Batch saved :  396
# Batch saved :  397
# Batch saved :  398
# Batch saved :  399
# Batch saved :  400
# Batch saved :  401
# Batch saved :  402
# Batch saved :  403
# Batch saved :  404
# Batch saved :  405
# Batch saved :  406
# Batch saved :  407
# Batch saved :  408
# Batch saved :  409
# Batch saved :  410
# Batch saved :  411
# Batch saved :  412
# Batch saved :  413
# Batch saved :  414
# Batch saved :  415
# Batch saved :  416
# Batch saved :  417
# Batch saved :  418
# Batch saved :  419
# Batch saved :  420
# Batch saved :  421
# Batch saved :  422
# Batch saved :  423
# Batch saved :  424
# Batch saved :  425
# Batch saved :  426
# Batch saved :  427
# Batch saved :  428
# Batch saved :  429
# Batch saved :  430
# Batch saved :  431
# Batch saved :  432
# Batch saved :  433
# Batch saved :  434
# Batch saved :  435
# Batch saved :  436
# Batch saved :  437
# Batch saved :  438
# Batch saved :  439
# Batch saved :  440
# Batch saved :  441
# Batch saved :  442
# Batch saved :  443
# Batch saved :  444
# Batch saved :  445
# Batch saved :  446
# Batch saved :  447
# Batch saved :  448
# Batch saved :  449
# Batch saved :  450
# Batch saved :  451
# Batch saved :  452
# Batch saved :  453
# Batch saved :  454
# Batch saved :  455
# Batch saved :  456
# Batch saved :  457
# Batch saved :  458
# Batch saved :  459
#
# left_data :  (46, 128, 431, 3)
# Batch saved :  460
# Batch saved :  461
# Batch saved :  462
# Batch saved :  463
# Batch saved :  464
# Batch saved :  465
# Batch saved :  466
# Batch saved :  467
# Batch saved :  468
# Batch saved :  469
# Batch saved :  470
# Batch saved :  471
# Batch saved :  472
# Batch saved :  473
# Batch saved :  474
# Batch saved :  475
# Batch saved :  476
# Batch saved :  477
# Batch saved :  478
# Batch saved :  479
# Batch saved :  480
# Batch saved :  481
# Batch saved :  482
# Batch saved :  483
# Batch saved :  484
# Batch saved :  485
# Batch saved :  486
# Batch saved :  487
# Batch saved :  488
# Batch saved :  489
# Batch saved :  490
# Batch saved :  491
# Batch saved :  492
# Batch saved :  493
# Batch saved :  494
# Batch saved :  495
# Batch saved :  496
# Batch saved :  497
# Batch saved :  498
# Batch saved :  499
# Batch saved :  500
# Batch saved :  501
# Batch saved :  502
# Batch saved :  503
# Batch saved :  504
# Batch saved :  505
# Batch saved :  506
# Batch saved :  507
# Batch saved :  508
# Batch saved :  509
# Batch saved :  510
# Batch saved :  511
# Batch saved :  512
# Batch saved :  513
# Batch saved :  514
# Batch saved :  515
# Batch saved :  516
# Batch saved :  517
# Batch saved :  518
# Batch saved :  519
# Batch saved :  520
# Batch saved :  521
# Batch saved :  522
# Batch saved :  523
# Batch saved :  524
# Batch saved :  525
#
# left_data :  (31, 128, 431, 3)
# Batch saved :  526
# Batch saved :  527
# Batch saved :  528
# Batch saved :  529
# Batch saved :  530
# Batch saved :  531
# Batch saved :  532
# Batch saved :  533
# Batch saved :  534
# Batch saved :  535
# Batch saved :  536
# Batch saved :  537
# Batch saved :  538
# Batch saved :  539
# Batch saved :  540
# Batch saved :  541
# Batch saved :  542
# Batch saved :  543
# Batch saved :  544
# Batch saved :  545
# Batch saved :  546
# Batch saved :  547
# Batch saved :  548
# Batch saved :  549
# Batch saved :  550
# Batch saved :  551
# Batch saved :  552
# Batch saved :  553
# Batch saved :  554
# Batch saved :  555
# Batch saved :  556
# Batch saved :  557
# Batch saved :  558
# Batch saved :  559
# Batch saved :  560
# Batch saved :  561
# Batch saved :  562
# Batch saved :  563
# Batch saved :  564
# Batch saved :  565
# Batch saved :  566
# Batch saved :  567
# Batch saved :  568
# Batch saved :  569
# Batch saved :  570
# Batch saved :  571
# Batch saved :  572
# Batch saved :  573
# Batch saved :  574
# Batch saved :  575
# Batch saved :  576
# Batch saved :  577
# Batch saved :  578
# Batch saved :  579
# Batch saved :  580
# Batch saved :  581
# Batch saved :  582
# Batch saved :  583
# Batch saved :  584
# Batch saved :  585
# Batch saved :  586
# Batch saved :  587
# Batch saved :  588
# Batch saved :  589
# Batch saved :  590
#
# left_data :  (57, 128, 431, 3)
# Batch saved :  591
# Batch saved :  592
# Batch saved :  593
# Batch saved :  594
# Batch saved :  595
# Batch saved :  596
# Batch saved :  597
# Batch saved :  598
# Batch saved :  599
# Batch saved :  600
# Batch saved :  601
# Batch saved :  602
# Batch saved :  603
# Batch saved :  604
# Batch saved :  605
# Batch saved :  606
# Batch saved :  607
# Batch saved :  608
# Batch saved :  609
# Batch saved :  610
# Batch saved :  611
# Batch saved :  612
# Batch saved :  613
# Batch saved :  614
# Batch saved :  615
# Batch saved :  616
# Batch saved :  617
# Batch saved :  618
# Batch saved :  619
# Batch saved :  620
# Batch saved :  621
# Batch saved :  622
# Batch saved :  623
# Batch saved :  624
# Batch saved :  625
# Batch saved :  626
# Batch saved :  627
# Batch saved :  628
# Batch saved :  629
# Batch saved :  630
# Batch saved :  631
# Batch saved :  632
# Batch saved :  633
# Batch saved :  634
# Batch saved :  635
# Batch saved :  636
# Batch saved :  637
# Batch saved :  638
# Batch saved :  639
# Batch saved :  640
# Batch saved :  641
# Batch saved :  642
# Batch saved :  643
# Batch saved :  644
# Batch saved :  645
# Batch saved :  646
# Batch saved :  647
# Batch saved :  648
# Batch saved :  649
# Batch saved :  650
# Batch saved :  651
# Batch saved :  652
# Batch saved :  653
# Batch saved :  654
# Batch saved :  655
# Batch saved :  656
# Batch saved :  657
# Batch saved :  658
# Batch saved :  659
# Batch saved :  660
# Batch saved :  661
# Batch saved :  662
# Batch saved :  663
#
# left_data :  (3, 128, 431, 3)
# Batch saved :  664
# Batch saved :  665
# Batch saved :  666
# Batch saved :  667
# Batch saved :  668
# Batch saved :  669
# Batch saved :  670
# Batch saved :  671
# Batch saved :  672
# Batch saved :  673
# Batch saved :  674
# Batch saved :  675
# Batch saved :  676
# Batch saved :  677
# Batch saved :  678
# Batch saved :  679
# Batch saved :  680
# Batch saved :  681
# Batch saved :  682
# Batch saved :  683
# Batch saved :  684
# Batch saved :  685
# Batch saved :  686
# Batch saved :  687
# Batch saved :  688
# Batch saved :  689
# Batch saved :  690
# Batch saved :  691
# Batch saved :  692
# Batch saved :  693
# Batch saved :  694
# Batch saved :  695
# Batch saved :  696
# Batch saved :  697
# Batch saved :  698
# Batch saved :  699
# Batch saved :  700
# Batch saved :  701
# Batch saved :  702
# Batch saved :  703
# Batch saved :  704
# Batch saved :  705
# Batch saved :  706
# Batch saved :  707
# Batch saved :  708
# Batch saved :  709
# Batch saved :  710
# Batch saved :  711
# Batch saved :  712
# Batch saved :  713
# Batch saved :  714
# Batch saved :  715
# Batch saved :  716
# Batch saved :  717
# Batch saved :  718
# Batch saved :  719
# Batch saved :  720
# Batch saved :  721
# Batch saved :  722
# Batch saved :  723
# Batch saved :  724
# Batch saved :  725
# Batch saved :  726
# Batch saved :  727
# Batch saved :  728
# Batch saved :  729
# Batch saved :  730
# Batch saved :  731
# Batch saved :  732
#
# left_data :  (25, 128, 431, 3)
# Batch saved :  733
# Batch saved :  734
# Batch saved :  735
# Batch saved :  736
# Batch saved :  737
# Batch saved :  738
# Batch saved :  739
# Batch saved :  740
# Batch saved :  741
# Batch saved :  742
# Batch saved :  743
# Batch saved :  744
# Batch saved :  745
# Batch saved :  746
# Batch saved :  747
# Batch saved :  748
# Batch saved :  749
# Batch saved :  750
# Batch saved :  751
# Batch saved :  752
# Batch saved :  753
# Batch saved :  754
# Batch saved :  755
# Batch saved :  756
# Batch saved :  757
# Batch saved :  758
# Batch saved :  759
# Batch saved :  760
# Batch saved :  761
# Batch saved :  762
# Batch saved :  763
# Batch saved :  764
# Batch saved :  765
# Batch saved :  766
# Batch saved :  767
# Batch saved :  768
# Batch saved :  769
# Batch saved :  770
# Batch saved :  771
# Batch saved :  772
# Batch saved :  773
# Batch saved :  774
# Batch saved :  775
# Batch saved :  776
#
# left_data :  (25, 128, 431, 3)
# Batch saved :  777
# Batch saved :  778
# Batch saved :  779
# Batch saved :  780
# Batch saved :  781
# Batch saved :  782
# Batch saved :  783
# Batch saved :  784
# Batch saved :  785
# Batch saved :  786
# Batch saved :  787
# Batch saved :  788
# Batch saved :  789
# Batch saved :  790
# Batch saved :  791
# Batch saved :  792
# Batch saved :  793
# Batch saved :  794
# Batch saved :  795
# Batch saved :  796
# Batch saved :  797
# Batch saved :  798
# Batch saved :  799
# Batch saved :  800
# Batch saved :  801
# Batch saved :  802
# Batch saved :  803
# Batch saved :  804
# Batch saved :  805
# Batch saved :  806
# Batch saved :  807
# Batch saved :  808
# Batch saved :  809
# Batch saved :  810
# Batch saved :  811
# Batch saved :  812
# Batch saved :  813
# Batch saved :  814
# Batch saved :  815
# Batch saved :  816
# Batch saved :  817
# Batch saved :  818
# Batch saved :  819
# Batch saved :  820
# Batch saved :  821
# Batch saved :  822
# Batch saved :  823
# Batch saved :  824
# Batch saved :  825
# Batch saved :  826
# Batch saved :  827
# Batch saved :  828
# Batch saved :  829
# Batch saved :  830
# Batch saved :  831
# Batch saved :  832
# Batch saved :  833
# Batch saved :  834
# Batch saved :  835
# Batch saved :  836
# Batch saved :  837
# Batch saved :  838
# Batch saved :  839
# Batch saved :  840
# Batch saved :  841
# Batch saved :  842
#
# left_data :  (59, 128, 431, 3)
# Batch saved :  843
# Batch saved :  844
# Batch saved :  845
# Batch saved :  846
# Batch saved :  847
# Batch saved :  848
# Batch saved :  849
# Batch saved :  850
# Batch saved :  851
# Batch saved :  852
# Batch saved :  853
# Batch saved :  854
# Batch saved :  855
# Batch saved :  856
# Batch saved :  857
# Batch saved :  858
# Batch saved :  859
# Batch saved :  860
# Batch saved :  861
# Batch saved :  862
# Batch saved :  863
# Batch saved :  864
# Batch saved :  865
# Batch saved :  866
# Batch saved :  867
# Batch saved :  868
# Batch saved :  869
# Batch saved :  870
# Batch saved :  871
# Batch saved :  872
# Batch saved :  873
# Batch saved :  874
# Batch saved :  875
# Batch saved :  876
# Batch saved :  877
# Batch saved :  878
# Batch saved :  879
# Batch saved :  880
# Batch saved :  881
# Batch saved :  882
# Batch saved :  883
# Batch saved :  884
# Batch saved :  885
# Batch saved :  886
# Batch saved :  887
# Batch saved :  888
# Batch saved :  889
# Batch saved :  890
# Batch saved :  891
# Batch saved :  892
# Batch saved :  893
# Batch saved :  894
# Batch saved :  895
# Batch saved :  896
# Batch saved :  897
# Batch saved :  898
# Batch saved :  899
# Batch saved :  900
# Batch saved :  901
# Batch saved :  902
# Batch saved :  903
# Batch saved :  904
#
# left_data :  (58, 128, 431, 3)
# Batch saved :  905
# Batch saved :  906
# Batch saved :  907
# Batch saved :  908
# Batch saved :  909
# Batch saved :  910
# Batch saved :  911
# Batch saved :  912
# Batch saved :  913
# Batch saved :  914
# Batch saved :  915
# Batch saved :  916
# Batch saved :  917
# Batch saved :  918
# Batch saved :  919
# Batch saved :  920
# Batch saved :  921
# Batch saved :  922
# Batch saved :  923
# Batch saved :  924
# Batch saved :  925
# Batch saved :  926
# Batch saved :  927
# Batch saved :  928
# Batch saved :  929
# Batch saved :  930
# Batch saved :  931
# Batch saved :  932
# Batch saved :  933
# Batch saved :  934
# Batch saved :  935
# Batch saved :  936
# Batch saved :  937
# Batch saved :  938
# Batch saved :  939
# Batch saved :  940
# Batch saved :  941
# Batch saved :  942
# Batch saved :  943
# Batch saved :  944
# Batch saved :  945
# Batch saved :  946
# Batch saved :  947
# Batch saved :  948
# Batch saved :  949
# Batch saved :  950
# Batch saved :  951
# Batch saved :  952
# Batch saved :  953
# Batch saved :  954
# Batch saved :  955
# Batch saved :  956
# Batch saved :  957
# Batch saved :  958
# Batch saved :  959
# Batch saved :  960
# Batch saved :  961
# Batch saved :  962
# Batch saved :  963
# Batch saved :  964
# Batch saved :  965
#
# left_data :  (15, 128, 431, 3)
# Batch saved :  966
# Batch saved :  967
# Batch saved :  968
# Batch saved :  969
# Batch saved :  970
# Batch saved :  971
# Batch saved :  972
# Batch saved :  973
# Batch saved :  974
# Batch saved :  975
# Batch saved :  976
# Batch saved :  977
# Batch saved :  978
# Batch saved :  979
# Batch saved :  980
# Batch saved :  981
# Batch saved :  982
# Batch saved :  983
# Batch saved :  984
# Batch saved :  985
# Batch saved :  986
# Batch saved :  987
# Batch saved :  988
# Batch saved :  989
# Batch saved :  990
# Batch saved :  991
# Batch saved :  992
# Batch saved :  993
# Batch saved :  994
# Batch saved :  995
# Batch saved :  996
# Batch saved :  997
# Batch saved :  998
# Batch saved :  999
# Batch saved :  1000
# Batch saved :  1001
# Batch saved :  1002
# Batch saved :  1003
# Batch saved :  1004
# Batch saved :  1005
# Batch saved :  1006
# Batch saved :  1007
# Batch saved :  1008
# Batch saved :  1009
# Batch saved :  1010
# Batch saved :  1011
# Batch saved :  1012
# Batch saved :  1013
# Batch saved :  1014
# Batch saved :  1015
# Batch saved :  1016
# Batch saved :  1017
# Batch saved :  1018
# Batch saved :  1019
# Batch saved :  1020
# Batch saved :  1021
# Batch saved :  1022
# Batch saved :  1023
# Batch saved :  1024
# Batch saved :  1025
# Batch saved :  1026
# Batch saved :  1027
# Batch saved :  1028
# Batch saved :  1029
# Batch saved :  1030
# Batch saved :  1031
# Batch saved :  1032
# Batch saved :  1033
# Batch saved :  1034
# Batch saved :  1035
# Batch saved :  1036
# Batch saved :  1037
# Batch saved :  1038
# Batch saved :  1039
#
# left_data :  (60, 128, 431, 3)
# Batch saved :  1040
# Batch saved :  1041
# Batch saved :  1042
# Batch saved :  1043
# Batch saved :  1044
# Batch saved :  1045
# Batch saved :  1046
# Batch saved :  1047
# Batch saved :  1048
# Batch saved :  1049
# Batch saved :  1050
# Batch saved :  1051
# Batch saved :  1052
# Batch saved :  1053
# Batch saved :  1054
# Batch saved :  1055
# Batch saved :  1056
# Batch saved :  1057
# Batch saved :  1058
# Batch saved :  1059
# Batch saved :  1060
# Batch saved :  1061
# Batch saved :  1062
# Batch saved :  1063
# Batch saved :  1064
# Batch saved :  1065
# Batch saved :  1066
# Batch saved :  1067
# Batch saved :  1068
# Batch saved :  1069
# Batch saved :  1070
# Batch saved :  1071
# Batch saved :  1072
# Batch saved :  1073
# Batch saved :  1074
# Batch saved :  1075
# Batch saved :  1076
# Batch saved :  1077
# Batch saved :  1078
# Batch saved :  1079
# Batch saved :  1080
# Batch saved :  1081
# Batch saved :  1082
# Batch saved :  1083
# Batch saved :  1084
# Batch saved :  1085
# Batch saved :  1086
# Batch saved :  1087
# Batch saved :  1088
# Batch saved :  1089
# Batch saved :  1090
# Batch saved :  1091
# Batch saved :  1092
# Batch saved :  1093
# Batch saved :  1094
# Batch saved :  1095
# Batch saved :  1096
# Batch saved :  1097
# Batch saved :  1098
# Batch saved :  1099
# Batch saved :  1100
# Batch saved :  1101
# Batch saved :  1102
# Batch saved :  1103
# Batch saved :  1104
# Batch saved :  1105
# Batch saved :  1106
# Batch saved :  1107
# Batch saved :  1108
# Batch saved :  1109
# Batch saved :  1110
# Batch saved :  1111
#
# left_data :  (42, 128, 431, 3)
# Batch saved :  1112
# Batch saved :  1113
# Batch saved :  1114
# Batch saved :  1115
# Batch saved :  1116
# Batch saved :  1117
# Batch saved :  1118
# Batch saved :  1119
# Batch saved :  1120
# Batch saved :  1121
# Batch saved :  1122
# Batch saved :  1123
# Batch saved :  1124
# Batch saved :  1125
# Batch saved :  1126
# Batch saved :  1127
# Batch saved :  1128
# Batch saved :  1129
# Batch saved :  1130
# Batch saved :  1131
# Batch saved :  1132
# Batch saved :  1133
# Batch saved :  1134
# Batch saved :  1135
# Batch saved :  1136
# Batch saved :  1137
# Batch saved :  1138
# Batch saved :  1139
# Batch saved :  1140
# Batch saved :  1141
# Batch saved :  1142
# Batch saved :  1143
# Batch saved :  1144
# Batch saved :  1145
# Batch saved :  1146
# Batch saved :  1147
# Batch saved :  1148
# Batch saved :  1149
# Batch saved :  1150
# Batch saved :  1151
# Batch saved :  1152
# Batch saved :  1153
# Batch saved :  1154
# Batch saved :  1155
# Batch saved :  1156
# Batch saved :  1157
# Batch saved :  1158
# Batch saved :  1159
# Batch saved :  1160
# Batch saved :  1161
# Batch saved :  1162
# Batch saved :  1163
# Batch saved :  1164
# Batch saved :  1165
# Batch saved :  1166
# Batch saved :  1167
# Batch saved :  1168
# Batch saved :  1169
# Batch saved :  1170
# Batch saved :  1171
# Batch saved :  1172
# Batch saved :  1173
#
# left_data :  (43, 128, 431, 3)
# Batch saved :  1174
# Batch saved :  1175
# Batch saved :  1176
# Batch saved :  1177
# Batch saved :  1178
# Batch saved :  1179
# Batch saved :  1180
# Batch saved :  1181
# Batch saved :  1182
# Batch saved :  1183
# Batch saved :  1184
# Batch saved :  1185
# Batch saved :  1186
# Batch saved :  1187
# Batch saved :  1188
# Batch saved :  1189
# Batch saved :  1190
# Batch saved :  1191
# Batch saved :  1192
# Batch saved :  1193
# Batch saved :  1194
# Batch saved :  1195
# Batch saved :  1196
# Batch saved :  1197
# Batch saved :  1198
# Batch saved :  1199
# Batch saved :  1200
# Batch saved :  1201
# Batch saved :  1202
# Batch saved :  1203
# Batch saved :  1204
# Batch saved :  1205
# Batch saved :  1206
# Batch saved :  1207
# Batch saved :  1208
# Batch saved :  1209
# Batch saved :  1210
# Batch saved :  1211
# Batch saved :  1212
# Batch saved :  1213
# Batch saved :  1214
# Batch saved :  1215
# Batch saved :  1216
# Batch saved :  1217
# Batch saved :  1218
# Batch saved :  1219
# Batch saved :  1220
# Batch saved :  1221
# Batch saved :  1222
# Batch saved :  1223
# Batch saved :  1224
# Batch saved :  1225
# Batch saved :  1226
# Batch saved :  1227
# Batch saved :  1228
# Batch saved :  1229
# Batch saved :  1230
# Batch saved :  1231
# Batch saved :  1232
# Batch saved :  1233
#
# left_data :  (38, 128, 431, 3)
# Batch saved :  1234
# Batch saved :  1235
# Batch saved :  1236
# Batch saved :  1237
# Batch saved :  1238
# Batch saved :  1239
# Batch saved :  1240
# Batch saved :  1241
# Batch saved :  1242
# Batch saved :  1243
# Batch saved :  1244
# Batch saved :  1245
# Batch saved :  1246
# Batch saved :  1247
# Batch saved :  1248
# Batch saved :  1249
# Batch saved :  1250
# Batch saved :  1251
# Batch saved :  1252
# Batch saved :  1253
# Batch saved :  1254
# Batch saved :  1255
# Batch saved :  1256
# Batch saved :  1257
# Batch saved :  1258
# Batch saved :  1259
# Batch saved :  1260
# Batch saved :  1261
# Batch saved :  1262
# Batch saved :  1263
# Batch saved :  1264
# Batch saved :  1265
# Batch saved :  1266
# Batch saved :  1267
# Batch saved :  1268
# Batch saved :  1269
# Batch saved :  1270
# Batch saved :  1271
# Batch saved :  1272
# Batch saved :  1273
# Batch saved :  1274
# Batch saved :  1275
# Batch saved :  1276
# Batch saved :  1277
# Batch saved :  1278
# Batch saved :  1279
# Batch saved :  1280
# Batch saved :  1281
# Batch saved :  1282
# Batch saved :  1283
# Batch saved :  1284
# Batch saved :  1285
# Batch saved :  1286
# Batch saved :  1287
# Batch saved :  1288
# Batch saved :  1289
# Batch saved :  1290
# Batch saved :  1291
# Batch saved :  1292
# Batch saved :  1293
# Batch saved :  1294
# Batch saved :  1295
# Batch saved :  1296
# Batch saved :  1297
# Batch saved :  1298
# Batch saved :  1299
# Batch saved :  1300
# Batch saved :  1301
#
# left_data :  (35, 128, 431, 3)
# Batch saved :  1302
# Batch saved :  1303
# Batch saved :  1304
# Batch saved :  1305
# Batch saved :  1306
# Batch saved :  1307
# Batch saved :  1308
# Batch saved :  1309
# Batch saved :  1310
# Batch saved :  1311
# Batch saved :  1312
# Batch saved :  1313
# Batch saved :  1314
# Batch saved :  1315
# Batch saved :  1316
# Batch saved :  1317
# Batch saved :  1318
# Batch saved :  1319
# Batch saved :  1320
# Batch saved :  1321
# Batch saved :  1322
# Batch saved :  1323
# Batch saved :  1324
# Batch saved :  1325
# Batch saved :  1326
# Batch saved :  1327
# Batch saved :  1328
# Batch saved :  1329
# Batch saved :  1330
# Batch saved :  1331
# Batch saved :  1332
# Batch saved :  1333
# Batch saved :  1334
# Batch saved :  1335
# Batch saved :  1336
# Batch saved :  1337
# Batch saved :  1338
# Batch saved :  1339
# Batch saved :  1340
# Batch saved :  1341
# Batch saved :  1342
# Batch saved :  1343
# Batch saved :  1344
# Batch saved :  1345
# Batch saved :  1346
# Batch saved :  1347
# Batch saved :  1348
# Batch saved :  1349
# Batch saved :  1350
# Batch saved :  1351
# Batch saved :  1352
# Batch saved :  1353
# Batch saved :  1354
# Batch saved :  1355
# Batch saved :  1356
# Batch saved :  1357
# Batch saved :  1358
# Batch saved :  1359
# Batch saved :  1360
# Batch saved :  1361
# Batch saved :  1362
# Batch saved :  1363
# Batch saved :  1364
# Batch saved :  1365
# Batch saved :  1366
# Batch saved :  1367
# Batch saved :  1368
# Batch saved :  1369
# Batch saved :  1370
# Batch saved :  1371
# Batch saved :  1372
#
# left_data :  (46, 128, 431, 3)
# Batch saved :  1373
# Batch saved :  1374
# Batch saved :  1375
# Batch saved :  1376
# Batch saved :  1377
# Batch saved :  1378
# Batch saved :  1379
# Batch saved :  1380
# Batch saved :  1381
# Batch saved :  1382
# Batch saved :  1383
# Batch saved :  1384
# Batch saved :  1385
# Batch saved :  1386
# Batch saved :  1387
# Batch saved :  1388
# Batch saved :  1389
# Batch saved :  1390
# Batch saved :  1391
# Batch saved :  1392
# Batch saved :  1393
# Batch saved :  1394
# Batch saved :  1395
# Batch saved :  1396
# Batch saved :  1397
# Batch saved :  1398
# Batch saved :  1399
# Batch saved :  1400
# Batch saved :  1401
# Batch saved :  1402
# Batch saved :  1403
# Batch saved :  1404
# Batch saved :  1405
# Batch saved :  1406
# Batch saved :  1407
# Batch saved :  1408
# Batch saved :  1409
# Batch saved :  1410
# Batch saved :  1411
# Batch saved :  1412
# Batch saved :  1413
# Batch saved :  1414
# Batch saved :  1415
# Batch saved :  1416
# Batch saved :  1417
# Batch saved :  1418
# Batch saved :  1419
# Batch saved :  1420
# Batch saved :  1421
# Batch saved :  1422
# Batch saved :  1423
# Batch saved :  1424
# Batch saved :  1425
# Batch saved :  1426
# Batch saved :  1427
# Batch saved :  1428
# Batch saved :  1429
# Batch saved :  1430
# Batch saved :  1431
# Batch saved :  1432
# Batch saved :  1433
# Batch saved :  1434
# Batch saved :  1435
# Batch saved :  1436
# Batch saved :  1437
#
# left_data :  (29, 128, 431, 3)
# Batch saved :  1438
# Batch saved :  1439
# Batch saved :  1440
# Batch saved :  1441
# Batch saved :  1442
# Batch saved :  1443
# Batch saved :  1444
# Batch saved :  1445
# Batch saved :  1446
# Batch saved :  1447
# Batch saved :  1448
# Batch saved :  1449
# Batch saved :  1450
# Batch saved :  1451
# Batch saved :  1452
# Batch saved :  1453
# Batch saved :  1454
# Batch saved :  1455
# Batch saved :  1456
# Batch saved :  1457
# Batch saved :  1458
# Batch saved :  1459
# Batch saved :  1460
# Batch saved :  1461
# Batch saved :  1462
# Batch saved :  1463
# Batch saved :  1464
# Batch saved :  1465
# Batch saved :  1466
# Batch saved :  1467
# Batch saved :  1468
# Batch saved :  1469
# Batch saved :  1470
# Batch saved :  1471
# Batch saved :  1472
# Batch saved :  1473
# Batch saved :  1474
# Batch saved :  1475
# Batch saved :  1476
# Batch saved :  1477
# Batch saved :  1478
# Batch saved :  1479
# Batch saved :  1480
# Batch saved :  1481
# Batch saved :  1482
# Batch saved :  1483
# Batch saved :  1484
# Batch saved :  1485
# Batch saved :  1486
# Batch saved :  1487
# Batch saved :  1488
# Batch saved :  1489
# Batch saved :  1490
# Batch saved :  1491
# Batch saved :  1492
# Batch saved :  1493
# Batch saved :  1494
# Batch saved :  1495
# Batch saved :  1496
# Batch saved :  1497
#
# left_data :  (11, 128, 431, 3)
# Batch saved :  1498
# Batch saved :  1499
# Batch saved :  1500
# Batch saved :  1501
# Batch saved :  1502
# Batch saved :  1503
# Batch saved :  1504
# Batch saved :  1505
# Batch saved :  1506
# Batch saved :  1507
# Batch saved :  1508
# Batch saved :  1509
# Batch saved :  1510
# Batch saved :  1511
# Batch saved :  1512
# Batch saved :  1513
# Batch saved :  1514
# Batch saved :  1515
# Batch saved :  1516
# Batch saved :  1517
# Batch saved :  1518
# Batch saved :  1519
# Batch saved :  1520
# Batch saved :  1521
# Batch saved :  1522
# Batch saved :  1523
# Batch saved :  1524
# Batch saved :  1525
# Batch saved :  1526
# Batch saved :  1527
# Batch saved :  1528
# Batch saved :  1529
# Batch saved :  1530
# Batch saved :  1531
# Batch saved :  1532
# Batch saved :  1533
# Batch saved :  1534
# Batch saved :  1535
# Batch saved :  1536
# Batch saved :  1537
# Batch saved :  1538
# Batch saved :  1539
# Batch saved :  1540
# Batch saved :  1541
# Batch saved :  1542
# Batch saved :  1543
# Batch saved :  1544
# Batch saved :  1545
# Batch saved :  1546
# Batch saved :  1547
# Batch saved :  1548
# Batch saved :  1549
# Batch saved :  1550
# Batch saved :  1551
# Batch saved :  1552
# Batch saved :  1553
# Batch saved :  1554
#
# left_data :  (54, 128, 431, 3)
# Batch saved :  1555
# Batch saved :  1556
# Batch saved :  1557
# Batch saved :  1558
# Batch saved :  1559
# Batch saved :  1560
# Batch saved :  1561
# Batch saved :  1562
# Batch saved :  1563
# Batch saved :  1564
# Batch saved :  1565
# Batch saved :  1566
# Batch saved :  1567
# Batch saved :  1568
# Batch saved :  1569
# Batch saved :  1570
# Batch saved :  1571
# Batch saved :  1572
# Batch saved :  1573
# Batch saved :  1574
# Batch saved :  1575
# Batch saved :  1576
# Batch saved :  1577
# Batch saved :  1578
# Batch saved :  1579
# Batch saved :  1580
# Batch saved :  1581
# Batch saved :  1582
# Batch saved :  1583
# Batch saved :  1584
# Batch saved :  1585
# Batch saved :  1586
# Batch saved :  1587
# Batch saved :  1588
# Batch saved :  1589
# Batch saved :  1590
# Batch saved :  1591
# Batch saved :  1592
# Batch saved :  1593
# Batch saved :  1594
# Batch saved :  1595
# Batch saved :  1596
# Batch saved :  1597
# Batch saved :  1598
# Batch saved :  1599
# Batch saved :  1600
# Batch saved :  1601
# Batch saved :  1602
# Batch saved :  1603
# Batch saved :  1604
# Batch saved :  1605
# Batch saved :  1606
# Batch saved :  1607
# Batch saved :  1608
# Batch saved :  1609
# Batch saved :  1610
# Batch saved :  1611
# Batch saved :  1612
# Batch saved :  1613
# Batch saved :  1614
# Batch saved :  1615
# Batch saved :  1616
#
# left_data :  (61, 128, 431, 3)
# Batch saved :  1617
# Batch saved :  1618
# Batch saved :  1619
# Batch saved :  1620
# Batch saved :  1621
# Batch saved :  1622
# Batch saved :  1623
# Batch saved :  1624
# Batch saved :  1625
# Batch saved :  1626
# Batch saved :  1627
# Batch saved :  1628
# Batch saved :  1629
# Batch saved :  1630
# Batch saved :  1631
# Batch saved :  1632
# Batch saved :  1633
# Batch saved :  1634
# Batch saved :  1635
# Batch saved :  1636
# Batch saved :  1637
# Batch saved :  1638
# Batch saved :  1639
# Batch saved :  1640
# Batch saved :  1641
# Batch saved :  1642
# Batch saved :  1643
# Batch saved :  1644
# Batch saved :  1645
# Batch saved :  1646
# Batch saved :  1647
# Batch saved :  1648
# Batch saved :  1649
# Batch saved :  1650
# Batch saved :  1651
# Batch saved :  1652
# Batch saved :  1653
# Batch saved :  1654
# Batch saved :  1655
# Batch saved :  1656
# Batch saved :  1657
# Batch saved :  1658
# Batch saved :  1659
# Batch saved :  1660
# Batch saved :  1661
# Batch saved :  1662
# Batch saved :  1663
# Batch saved :  1664
# Batch saved :  1665
# Batch saved :  1666
# Batch saved :  1667
# Batch saved :  1668
# Batch saved :  1669
# Batch saved :  1670
# Batch saved :  1671
# Batch saved :  1672
# Batch saved :  1673
# Batch saved :  1674
# Batch saved :  1675
# Batch saved :  1676
# Batch saved :  1677
# Batch saved :  1678
# Batch saved :  1679
# Batch saved :  1680
#
# left_data :  (10, 128, 431, 3)
# Batch saved :  1681
# Batch saved :  1682
# Batch saved :  1683
# Batch saved :  1684
# Batch saved :  1685
# Batch saved :  1686
# Batch saved :  1687
# Batch saved :  1688
# Batch saved :  1689
# Batch saved :  1690
# Batch saved :  1691
# Batch saved :  1692
# Batch saved :  1693
# Batch saved :  1694
# Batch saved :  1695
# Batch saved :  1696
# Batch saved :  1697
# Batch saved :  1698
# Batch saved :  1699
# Batch saved :  1700
# Batch saved :  1701
# Batch saved :  1702
# Batch saved :  1703
# Batch saved :  1704
# Batch saved :  1705
# Batch saved :  1706
# Batch saved :  1707
# Batch saved :  1708
# Batch saved :  1709
# Batch saved :  1710
# Batch saved :  1711
# Batch saved :  1712
# Batch saved :  1713
# Batch saved :  1714
# Batch saved :  1715
# Batch saved :  1716
# Batch saved :  1717
# Batch saved :  1718
# Batch saved :  1719
# Batch saved :  1720
# Batch saved :  1721
# Batch saved :  1722
# Batch saved :  1723
# Batch saved :  1724
# Batch saved :  1725
# Batch saved :  1726
# Batch saved :  1727
# Batch saved :  1728
# Batch saved :  1729
# Batch saved :  1730
# Batch saved :  1731
# Batch saved :  1732
# Batch saved :  1733
# Batch saved :  1734
# Batch saved :  1735
# Batch saved :  1736
# Batch saved :  1737
# Batch saved :  1738
# Batch saved :  1739
# Batch saved :  1740
# Batch saved :  1741
# Batch saved :  1742
# Batch saved :  1743
# Batch saved :  1744
#
# left_data :  (63, 128, 431, 3)
# Batch saved :  1745
# Batch saved :  1746
# Batch saved :  1747
# Batch saved :  1748
# Batch saved :  1749
# Batch saved :  1750
# Batch saved :  1751
# Batch saved :  1752
# Batch saved :  1753
# Batch saved :  1754
# Batch saved :  1755
# Batch saved :  1756
# Batch saved :  1757
# Batch saved :  1758
# Batch saved :  1759
# Batch saved :  1760
# Batch saved :  1761
# Batch saved :  1762
# Batch saved :  1763
# Batch saved :  1764
# Batch saved :  1765
# Batch saved :  1766
# Batch saved :  1767
# Batch saved :  1768
# Batch saved :  1769
# Batch saved :  1770
# Batch saved :  1771
# Batch saved :  1772
# Batch saved :  1773
# Batch saved :  1774
# Batch saved :  1775
# Batch saved :  1776
# Batch saved :  1777
# Batch saved :  1778
# Batch saved :  1779
# Batch saved :  1780
# Batch saved :  1781
# Batch saved :  1782
# Batch saved :  1783
# Batch saved :  1784
# Batch saved :  1785
# Batch saved :  1786
# Batch saved :  1787
# Batch saved :  1788
# Batch saved :  1789
# Batch saved :  1790
# Batch saved :  1791
# Batch saved :  1792
# Batch saved :  1793
# Batch saved :  1794
# Batch saved :  1795
# Batch saved :  1796
# Batch saved :  1797
# Batch saved :  1798
# Batch saved :  1799
# Batch saved :  1800
# Batch saved :  1801
# Batch saved :  1802
# Batch saved :  1803
# Batch saved :  1804
# Batch saved :  1805
# Batch saved :  1806
# Batch saved :  1807
# Batch saved :  1808
# Batch saved :  1809
# Batch saved :  1810
# Batch saved :  1811
# Batch saved :  1812
# Batch saved :  1813
# Batch saved :  1814
#
# left_data :  (32, 128, 431, 3)
# Batch saved :  1815
# Batch saved :  1816
# Batch saved :  1817
# Batch saved :  1818
# Batch saved :  1819
# Batch saved :  1820
# Batch saved :  1821
# Batch saved :  1822
# Batch saved :  1823
# Batch saved :  1824
# Batch saved :  1825
# Batch saved :  1826
# Batch saved :  1827
# Batch saved :  1828
# Batch saved :  1829
# Batch saved :  1830
# Batch saved :  1831
# Batch saved :  1832
# Batch saved :  1833
# Batch saved :  1834
# Batch saved :  1835
# Batch saved :  1836
# Batch saved :  1837
# Batch saved :  1838
# Batch saved :  1839
# Batch saved :  1840
# Batch saved :  1841
# Batch saved :  1842
# Batch saved :  1843
# Batch saved :  1844
# Batch saved :  1845
# Batch saved :  1846
# Batch saved :  1847
# Batch saved :  1848
# Batch saved :  1849
# Batch saved :  1850
# Batch saved :  1851
# Batch saved :  1852
# Batch saved :  1853
# Batch saved :  1854
# Batch saved :  1855
# Batch saved :  1856
# Batch saved :  1857
# Batch saved :  1858
# Batch saved :  1859
# Batch saved :  1860
# Batch saved :  1861
# Batch saved :  1862
# Batch saved :  1863
# Batch saved :  1864
# Batch saved :  1865
# Batch saved :  1866
# Batch saved :  1867
# Batch saved :  1868
# Batch saved :  1869
# Batch saved :  1870
# Batch saved :  1871
# Batch saved :  1872
# Batch saved :  1873
# Batch saved :  1874
# Batch saved :  1875
# Batch saved :  1876
# Batch saved :  1877
# Batch saved :  1878
# Batch saved :  1879
# Batch saved :  1880
# Batch saved :  1881
# Batch saved :  1882
# Batch saved :  1883
# Batch saved :  1884
# Batch saved :  1885
#
# left_data :  (60, 128, 431, 3)
# Batch saved :  1886
# Batch saved :  1887
# Batch saved :  1888
# Batch saved :  1889
# Batch saved :  1890
# Batch saved :  1891
# Batch saved :  1892
# Batch saved :  1893
# Batch saved :  1894
# Batch saved :  1895
# Batch saved :  1896
# Batch saved :  1897
# Batch saved :  1898
# Batch saved :  1899
# Batch saved :  1900
# Batch saved :  1901
# Batch saved :  1902
# Batch saved :  1903
# Batch saved :  1904
# Batch saved :  1905
# Batch saved :  1906
# Batch saved :  1907
# Batch saved :  1908
# Batch saved :  1909
# Batch saved :  1910
# Batch saved :  1911
# Batch saved :  1912
# Batch saved :  1913
# Batch saved :  1914
# Batch saved :  1915
# Batch saved :  1916
# Batch saved :  1917
# Batch saved :  1918
# Batch saved :  1919
# Batch saved :  1920
# Batch saved :  1921
# Batch saved :  1922
# Batch saved :  1923
# Batch saved :  1924
# Batch saved :  1925
# Batch saved :  1926
# Batch saved :  1927
# Batch saved :  1928
# Batch saved :  1929
# Batch saved :  1930
# Batch saved :  1931
# Batch saved :  1932
# Batch saved :  1933
# Batch saved :  1934
# Batch saved :  1935
# Batch saved :  1936
# Batch saved :  1937
# Batch saved :  1938
# Batch saved :  1939
# Batch saved :  1940
# Batch saved :  1941
# Batch saved :  1942
# Batch saved :  1943
# Batch saved :  1944
# Batch saved :  1945
# Batch saved :  1946
# Batch saved :  1947
# Batch saved :  1948
# Batch saved :  1949
# Batch saved :  1950
# Batch saved :  1951
# Batch saved :  1952
# Batch saved :  1953
# Batch saved :  1954
#
# left_data :  (6, 128, 431, 3)
# Batch saved :  1955
# Batch saved :  1956
# Batch saved :  1957
# Batch saved :  1958
# Batch saved :  1959
# Batch saved :  1960
# Batch saved :  1961
# Batch saved :  1962
# Batch saved :  1963
# Batch saved :  1964
# Batch saved :  1965
# Batch saved :  1966
# Batch saved :  1967
# Batch saved :  1968
# Batch saved :  1969
# Batch saved :  1970
# Batch saved :  1971
# Batch saved :  1972
# Batch saved :  1973
# Batch saved :  1974
# Batch saved :  1975
# Batch saved :  1976
# Batch saved :  1977
# Batch saved :  1978
# Batch saved :  1979
# Batch saved :  1980
# Batch saved :  1981
# Batch saved :  1982
# Batch saved :  1983
# Batch saved :  1984
# Batch saved :  1985
# Batch saved :  1986
# Batch saved :  1987
# Batch saved :  1988
# Batch saved :  1989
# Batch saved :  1990
# Batch saved :  1991
# Batch saved :  1992
# Batch saved :  1993
# Batch saved :  1994
# Batch saved :  1995
# Batch saved :  1996
# Batch saved :  1997
# Batch saved :  1998
# Batch saved :  1999
# Batch saved :  2000
# Batch saved :  2001
# Batch saved :  2002
# Batch saved :  2003
# Batch saved :  2004
# Batch saved :  2005
# Batch saved :  2006
# Batch saved :  2007
# Batch saved :  2008
# Batch saved :  2009
# Batch saved :  2010
# Batch saved :  2011
# Batch saved :  2012
# Batch saved :  2013
# Batch saved :  2014
# Batch saved :  2015
# Batch saved :  2016
# Batch saved :  2017
# Batch saved :  2018
# Batch saved :  2019
# Batch saved :  2020
# Batch saved :  2021
#
# left_data :  (19, 128, 431, 3)
# Batch saved :  2022
# Batch saved :  2023
# Batch saved :  2024
# Batch saved :  2025
# Batch saved :  2026
# Batch saved :  2027
# Batch saved :  2028
# Batch saved :  2029
# Batch saved :  2030
# Batch saved :  2031
# Batch saved :  2032
# Batch saved :  2033
# Batch saved :  2034
# Batch saved :  2035
# Batch saved :  2036
# Batch saved :  2037
# Batch saved :  2038
# Batch saved :  2039
# Batch saved :  2040
# Batch saved :  2041
# Batch saved :  2042
# Batch saved :  2043
# Batch saved :  2044
# Batch saved :  2045
# Batch saved :  2046
# Batch saved :  2047
# Batch saved :  2048
# Batch saved :  2049
# Batch saved :  2050
# Batch saved :  2051
# Batch saved :  2052
# Batch saved :  2053
# Batch saved :  2054
# Batch saved :  2055
# Batch saved :  2056
# Batch saved :  2057
# Batch saved :  2058
# Batch saved :  2059
# Batch saved :  2060
# Batch saved :  2061
# Batch saved :  2062
# Batch saved :  2063
# Batch saved :  2064
# Batch saved :  2065
# Batch saved :  2066
# Batch saved :  2067
# Batch saved :  2068
# Batch saved :  2069
# Batch saved :  2070
# Batch saved :  2071
# Batch saved :  2072
# Batch saved :  2073
# Batch saved :  2074
# Batch saved :  2075
# Batch saved :  2076
# Batch saved :  2077
# Batch saved :  2078
# Batch saved :  2079
# Batch saved :  2080
# Batch saved :  2081
# Batch saved :  2082
# Batch saved :  2083
# Batch saved :  2084
# Batch saved :  2085
# Batch saved :  2086
# Batch saved :  2087
#
# left_data :  (8, 128, 431, 3)
# Batch saved :  2088
# Batch saved :  2089
# Batch saved :  2090
# Batch saved :  2091
# Batch saved :  2092
# Batch saved :  2093
# Batch saved :  2094
# Batch saved :  2095
# Batch saved :  2096
# Batch saved :  2097
# Batch saved :  2098
# Batch saved :  2099
# Batch saved :  2100
# Batch saved :  2101
# Batch saved :  2102
# Batch saved :  2103
# Batch saved :  2104
# Batch saved :  2105
# Batch saved :  2106
# Batch saved :  2107
# Batch saved :  2108
# Batch saved :  2109
# Batch saved :  2110
# Batch saved :  2111
# Batch saved :  2112
# Batch saved :  2113
# Batch saved :  2114
# Batch saved :  2115
# Batch saved :  2116
# Batch saved :  2117
# Batch saved :  2118
# Batch saved :  2119
# Batch saved :  2120
# Batch saved :  2121
# Batch saved :  2122
# Batch saved :  2123
# Batch saved :  2124
# Batch saved :  2125
# Batch saved :  2126
# Batch saved :  2127
# Batch saved :  2128
# Batch saved :  2129
# Batch saved :  2130
# Batch saved :  2131
# Batch saved :  2132
# Batch saved :  2133
# Batch saved :  2134
# Batch saved :  2135
# Batch saved :  2136
# Batch saved :  2137
# Batch saved :  2138
# Batch saved :  2139
# Batch saved :  2140
# Batch saved :  2141
# Batch saved :  2142
# Batch saved :  2143
# Batch saved :  2144
# Batch saved :  2145
# Batch saved :  2146
# Batch saved :  2147
# Batch saved :  2148
# Batch saved :  2149
# Batch saved :  2150
# Batch saved :  2151
# Batch saved :  2152
#
# left_data :  (31, 128, 431, 3)
# Batch saved :  2153
# Batch saved :  2154
# Batch saved :  2155
# Batch saved :  2156
# Batch saved :  2157
# Batch saved :  2158
# Batch saved :  2159
# Batch saved :  2160
# Batch saved :  2161
# Batch saved :  2162
# Batch saved :  2163
# Batch saved :  2164
# Batch saved :  2165
# Batch saved :  2166
# Batch saved :  2167
# Batch saved :  2168
# Batch saved :  2169
# Batch saved :  2170
# Batch saved :  2171
# Batch saved :  2172
# Batch saved :  2173
# Batch saved :  2174
# Batch saved :  2175
# Batch saved :  2176
# Batch saved :  2177
# Batch saved :  2178
# Batch saved :  2179
# Batch saved :  2180
# Batch saved :  2181
# Batch saved :  2182
# Batch saved :  2183
# Batch saved :  2184
# Batch saved :  2185
# Batch saved :  2186
# Batch saved :  2187
# Batch saved :  2188
# Batch saved :  2189
# Batch saved :  2190
# Batch saved :  2191
# Batch saved :  2192
# Batch saved :  2193
# Batch saved :  2194
# Batch saved :  2195
# Batch saved :  2196
# Batch saved :  2197
# Batch saved :  2198
# Batch saved :  2199
# Batch saved :  2200
# Batch saved :  2201
# Batch saved :  2202
# Batch saved :  2203
# Batch saved :  2204
# Batch saved :  2205
# Batch saved :  2206
# Batch saved :  2207
# Batch saved :  2208
# Batch saved :  2209
# Batch saved :  2210
#
# left_data :  (32, 128, 431, 3)
# Batch saved :  2211
# Batch saved :  2212
# Batch saved :  2213
# Batch saved :  2214
# Batch saved :  2215
# Batch saved :  2216
# Batch saved :  2217
# Batch saved :  2218
# Batch saved :  2219
# Batch saved :  2220
# Batch saved :  2221
# Batch saved :  2222
# Batch saved :  2223
# Batch saved :  2224
# Batch saved :  2225
# Batch saved :  2226
# Batch saved :  2227
# Batch saved :  2228
# Batch saved :  2229
# Batch saved :  2230
# Batch saved :  2231
# Batch saved :  2232
# Batch saved :  2233
# Batch saved :  2234
# Batch saved :  2235
# Batch saved :  2236
# Batch saved :  2237
# Batch saved :  2238
# Batch saved :  2239
# Batch saved :  2240
# Batch saved :  2241
# Batch saved :  2242
# Batch saved :  2243
# Batch saved :  2244
# Batch saved :  2245
# Batch saved :  2246
# Batch saved :  2247
# Batch saved :  2248
# Batch saved :  2249
# Batch saved :  2250
# Batch saved :  2251
# Batch saved :  2252
# Batch saved :  2253
# Batch saved :  2254
# Batch saved :  2255
# Batch saved :  2256
# Batch saved :  2257
# Batch saved :  2258
#
# left_data :  (30, 128, 431, 3)
# Batch saved :  2259
# Batch saved :  2260
# Batch saved :  2261
# Batch saved :  2262
# Batch saved :  2263
# Batch saved :  2264
# Batch saved :  2265
# Batch saved :  2266
# Batch saved :  2267
# Batch saved :  2268
# Batch saved :  2269
# Batch saved :  2270
# Batch saved :  2271
# Batch saved :  2272
# Batch saved :  2273
# Batch saved :  2274
# Batch saved :  2275
# Batch saved :  2276
# Batch saved :  2277
# Batch saved :  2278
# Batch saved :  2279
# Batch saved :  2280
# Batch saved :  2281
# Batch saved :  2282
# Batch saved :  2283
# Batch saved :  2284
# Batch saved :  2285
# Batch saved :  2286
# Batch saved :  2287
# Batch saved :  2288
# Batch saved :  2289
# Batch saved :  2290
# Batch saved :  2291
# Batch saved :  2292
# Batch saved :  2293
# Batch saved :  2294
# Batch saved :  2295
# Batch saved :  2296
# Batch saved :  2297
# Batch saved :  2298
# Batch saved :  2299
# Batch saved :  2300
# Batch saved :  2301
# Batch saved :  2302
# Batch saved :  2303
# Batch saved :  2304
# Batch saved :  2305
# Batch saved :  2306
# Batch saved :  2307
# Batch saved :  2308
# Batch saved :  2309
# Batch saved :  2310
# Batch saved :  2311
# Batch saved :  2312
# Batch saved :  2313
# Batch saved :  2314
# Batch saved :  2315
# Batch saved :  2316
# Batch saved :  2317
#
# left_data :  (57, 128, 431, 3)
# Batch saved :  2318
# Batch saved :  2319
# Batch saved :  2320
# Batch saved :  2321
# Batch saved :  2322
# Batch saved :  2323
# Batch saved :  2324
# Batch saved :  2325
# Batch saved :  2326
# Batch saved :  2327
# Batch saved :  2328
# Batch saved :  2329
# Batch saved :  2330
# Batch saved :  2331
# Batch saved :  2332
# Batch saved :  2333
# Batch saved :  2334
# Batch saved :  2335
# Batch saved :  2336
# Batch saved :  2337
# Batch saved :  2338
# Batch saved :  2339
# Batch saved :  2340
# Batch saved :  2341
# Batch saved :  2342
# Batch saved :  2343
# Batch saved :  2344
# Batch saved :  2345
# Batch saved :  2346
# Batch saved :  2347
# Batch saved :  2348
# Batch saved :  2349
# Batch saved :  2350
# Batch saved :  2351
# Batch saved :  2352
# Batch saved :  2353
# Batch saved :  2354
# Batch saved :  2355
# Batch saved :  2356
# Batch saved :  2357
# Batch saved :  2358
# Batch saved :  2359
# Batch saved :  2360
# Batch saved :  2361
# Batch saved :  2362
# Batch saved :  2363
# Batch saved :  2364
# Batch saved :  2365
# Batch saved :  2366
# Batch saved :  2367
# Batch saved :  2368
# Batch saved :  2369
# Batch saved :  2370
# Batch saved :  2371
# Batch saved :  2372
# Batch saved :  2373
# Batch saved :  2374
# Batch saved :  2375
# Batch saved :  2376
# Batch saved :  2377
# Batch saved :  2378
# Batch saved :  2379
# Batch saved :  2380
# Batch saved :  2381
# Batch saved :  2382
#
# left_data :  (29, 128, 431, 3)
# Batch saved :  2383
# Batch saved :  2384
# Batch saved :  2385
# Batch saved :  2386
# Batch saved :  2387
# Batch saved :  2388
# Batch saved :  2389
# Batch saved :  2390
# Batch saved :  2391
# Batch saved :  2392
# Batch saved :  2393
# Batch saved :  2394
# Batch saved :  2395
# Batch saved :  2396
# Batch saved :  2397
# Batch saved :  2398
# Batch saved :  2399
# Batch saved :  2400
# Batch saved :  2401
# Batch saved :  2402
# Batch saved :  2403
# Batch saved :  2404
# Batch saved :  2405
# Batch saved :  2406
# Batch saved :  2407
# Batch saved :  2408
# Batch saved :  2409
# Batch saved :  2410
# Batch saved :  2411
# Batch saved :  2412
# Batch saved :  2413
# Batch saved :  2414
# Batch saved :  2415
# Batch saved :  2416
# Batch saved :  2417
# Batch saved :  2418
# Batch saved :  2419
# Batch saved :  2420
# Batch saved :  2421
# Batch saved :  2422
# Batch saved :  2423
# Batch saved :  2424
# Batch saved :  2425
# Batch saved :  2426
# Batch saved :  2427
# Batch saved :  2428
# Batch saved :  2429
# Batch saved :  2430
# Batch saved :  2431
# Batch saved :  2432
# Batch saved :  2433
# Batch saved :  2434
# Batch saved :  2435
# Batch saved :  2436
# Batch saved :  2437
# Batch saved :  2438
# Batch saved :  2439
# Batch saved :  2440
# Batch saved :  2441
# Batch saved :  2442
# Batch saved :  2443
# Batch saved :  2444
# Batch saved :  2445
# Batch saved :  2446
# Batch saved :  2447
# Batch saved :  2448
# Batch saved :  2449
# Batch saved :  2450
# Batch saved :  2451
# Batch saved :  2452
# Batch saved :  2453
# Batch saved :  2454
# Batch saved :  2455
#
# left_data :  (29, 128, 431, 3)
# Batch saved :  2456
# Batch saved :  2457
# Batch saved :  2458
# Batch saved :  2459
# Batch saved :  2460
# Batch saved :  2461
# Batch saved :  2462
# Batch saved :  2463
# Batch saved :  2464
# Batch saved :  2465
# Batch saved :  2466
# Batch saved :  2467
# Batch saved :  2468
# Batch saved :  2469
# Batch saved :  2470
# Batch saved :  2471
# Batch saved :  2472
# Batch saved :  2473
# Batch saved :  2474
# Batch saved :  2475
# Batch saved :  2476
# Batch saved :  2477
# Batch saved :  2478
# Batch saved :  2479
# Batch saved :  2480
# Batch saved :  2481
# Batch saved :  2482
# Batch saved :  2483
# Batch saved :  2484
# Batch saved :  2485
# Batch saved :  2486
# Batch saved :  2487
# Batch saved :  2488
# Batch saved :  2489
# Batch saved :  2490
# Batch saved :  2491
# Batch saved :  2492
# Batch saved :  2493
# Batch saved :  2494
# Batch saved :  2495
# Batch saved :  2496
# Batch saved :  2497
# Batch saved :  2498
# Batch saved :  2499
# Batch saved :  2500
# Batch saved :  2501
# Batch saved :  2502
# Batch saved :  2503
# Batch saved :  2504
# Batch saved :  2505
# Batch saved :  2506
# Batch saved :  2507
# Batch saved :  2508
# Batch saved :  2509
# Batch saved :  2510
# Batch saved :  2511
# Batch saved :  2512
# Batch saved :  2513
# Batch saved :  2514
# Batch saved :  2515
# Batch saved :  2516
# Batch saved :  2517
# Batch saved :  2518
# Batch saved :  2519
# Batch saved :  2520
# Batch saved :  2521
#
# left_data :  (62, 128, 431, 3)
# Batch saved :  2522
# Batch saved :  2523
# Batch saved :  2524
# Batch saved :  2525
# Batch saved :  2526
# Batch saved :  2527
# Batch saved :  2528
# Batch saved :  2529
# Batch saved :  2530
# Batch saved :  2531
# Batch saved :  2532
# Batch saved :  2533
# Batch saved :  2534
# Batch saved :  2535
# Batch saved :  2536
# Batch saved :  2537
# Batch saved :  2538
# Batch saved :  2539
# Batch saved :  2540
# Batch saved :  2541
# Batch saved :  2542
# Batch saved :  2543
# Batch saved :  2544
# Batch saved :  2545
# Batch saved :  2546
# Batch saved :  2547
# Batch saved :  2548
# Batch saved :  2549
# Batch saved :  2550
# Batch saved :  2551
# Batch saved :  2552
# Batch saved :  2553
# Batch saved :  2554
# Batch saved :  2555
# Batch saved :  2556
# Batch saved :  2557
# Batch saved :  2558
# Batch saved :  2559
# Batch saved :  2560
# Batch saved :  2561
# Batch saved :  2562
# Batch saved :  2563
# Batch saved :  2564
# Batch saved :  2565
# Batch saved :  2566
# Batch saved :  2567
# Batch saved :  2568
# Batch saved :  2569
# Batch saved :  2570
# Batch saved :  2571
# Batch saved :  2572
# Batch saved :  2573
# Batch saved :  2574
# Batch saved :  2575
# Batch saved :  2576
# Batch saved :  2577
# Batch saved :  2578
# Batch saved :  2579
# Batch saved :  2580
# Batch saved :  2581
# Batch saved :  2582
# Batch saved :  2583
# Batch saved :  2584
# Batch saved :  2585
# Batch saved :  2586
# Batch saved :  2587
# Batch saved :  2588
# Batch saved :  2589
# Batch saved :  2590
# Batch saved :  2591
# Batch saved :  2592
# Batch saved :  2593
# Batch saved :  2594
# Batch saved :  2595
#
# left_data :  (17, 128, 431, 3)
# Batch saved :  2596
# Batch saved :  2597
# Batch saved :  2598
# Batch saved :  2599
# Batch saved :  2600
# Batch saved :  2601
# Batch saved :  2602
# Batch saved :  2603
# Batch saved :  2604
# Batch saved :  2605
# Batch saved :  2606
# Batch saved :  2607
# Batch saved :  2608
# Batch saved :  2609
# Batch saved :  2610
# Batch saved :  2611
# Batch saved :  2612
# Batch saved :  2613
# Batch saved :  2614
# Batch saved :  2615
# Batch saved :  2616
# Batch saved :  2617
# Batch saved :  2618
# Batch saved :  2619
# ...
# Batch saved :  4314
# Batch saved :  4315
# Batch saved :  4316
# Batch saved :  4317
# Batch saved :  4318
# Batch saved :  4319
# Batch saved :  4320
# Batch saved :  4321
# Batch saved :  4322
# Batch saved :  4323
# Batch saved :  4324
# Batch saved :  4325
# Batch saved :  4326
# Batch saved :  4327
# Batch saved :  4328
# Batch saved :  4329
# Batch saved :  4330
# Batch saved :  4331
# Batch saved :  4332
# Batch saved :  4333
# Batch saved :  4334
# Batch saved :  4335
# Batch saved :  4336
# Batch saved :  4337
# Batch saved :  4338
# Batch saved :  4339
# Batch saved :  4340
# Batch saved :  4341
# Batch saved :  4342
# Batch saved :  4343
# Batch saved :  4344
# Batch saved :  4345
# Batch saved :  4346
# Batch saved :  4347
# Batch saved :  4348
# Batch saved :  4349
# Batch saved :  4350
# Batch saved :  4351
# Batch saved :  4352
# Batch saved :  4353
# Batch saved :  4354
# Batch saved :  4355
#
# left_data :  (61, 128, 431, 3)
# Batch saved :  4356
# Batch saved :  4357
# Batch saved :  4358
# Batch saved :  4359
# Batch saved :  4360
# Batch saved :  4361
# Batch saved :  4362
# Batch saved :  4363
# Batch saved :  4364
# Batch saved :  4365
# Batch saved :  4366
# Batch saved :  4367
# Batch saved :  4368
# Batch saved :  4369
# Batch saved :  4370
# Batch saved :  4371
# Batch saved :  4372
# Batch saved :  4373
# Batch saved :  4374
# Batch saved :  4375
# Batch saved :  4376
# Batch saved :  4377
# Batch saved :  4378
# Batch saved :  4379
# Batch saved :  4380
# Batch saved :  4381
# Batch saved :  4382
# Batch saved :  4383
# Batch saved :  4384
# Batch saved :  4385
# Batch saved :  4386
# Batch saved :  4387
# Batch saved :  4388
# Batch saved :  4389
# Batch saved :  4390
# Batch saved :  4391
# Batch saved :  4392
# Batch saved :  4393
# Batch saved :  4394
# Batch saved :  4395
# Batch saved :  4396
# Batch saved :  4397
# Batch saved :  4398
# Batch saved :  4399
# Batch saved :  4400
# Batch saved :  4401
# Batch saved :  4402
# Batch saved :  4403
# Batch saved :  4404
# Batch saved :  4405
# Batch saved :  4406
# Batch saved :  4407
# Batch saved :  4408
# Batch saved :  4409
# Batch saved :  4410
# Batch saved :  4411
# Batch saved :  4412
# Batch saved :  4413
# Batch saved :  4414
# Batch saved :  4415
# Batch saved :  4416
# Batch saved :  4417
# Batch saved :  4418
# Batch saved :  4419
# Batch saved :  4420
# Batch saved :  4421
# Batch saved :  4422
# Batch saved :  4423
# Batch saved :  4424
#
# left_data :  (23, 128, 431, 3)
# Batch saved :  4425
# Batch saved :  4426
# Batch saved :  4427
# Batch saved :  4428
# Batch saved :  4429
# Batch saved :  4430
# Batch saved :  4431
# Batch saved :  4432
# Batch saved :  4433
# Batch saved :  4434
# Batch saved :  4435
# Batch saved :  4436
# Batch saved :  4437
# Batch saved :  4438
# Batch saved :  4439
# Batch saved :  4440
# Batch saved :  4441
# Batch saved :  4442
# Batch saved :  4443
# Batch saved :  4444
# Batch saved :  4445
# Batch saved :  4446
# Batch saved :  4447
# Batch saved :  4448
# Batch saved :  4449
# Batch saved :  4450
# Batch saved :  4451
# Batch saved :  4452
# Batch saved :  4453
# Batch saved :  4454
# Batch saved :  4455
# Batch saved :  4456
# Batch saved :  4457
# Batch saved :  4458
# Batch saved :  4459
# Batch saved :  4460
# Batch saved :  4461
# Batch saved :  4462
# Batch saved :  4463
# Batch saved :  4464
# Batch saved :  4465
# Batch saved :  4466
# Batch saved :  4467
# Batch saved :  4468
# Batch saved :  4469
# Batch saved :  4470
# Batch saved :  4471
# Batch saved :  4472
# Batch saved :  4473
# Batch saved :  4474
# Batch saved :  4475
# Batch saved :  4476
# Batch saved :  4477
# Batch saved :  4478
# Batch saved :  4479
# Batch saved :  4480
# Batch saved :  4481
# Batch saved :  4482
# Batch saved :  4483
# Batch saved :  4484
# Batch saved :  4485
# Batch saved :  4486
# Batch saved :  4487
# Batch saved :  4488
# Batch saved :  4489
# Batch saved :  4490
# Batch saved :  4491
#
# left_data :  (41, 128, 431, 3)
# Batch saved :  4492
# Batch saved :  4493
# Batch saved :  4494
# Batch saved :  4495
# Batch saved :  4496
# Batch saved :  4497
# Batch saved :  4498
# Batch saved :  4499
# Batch saved :  4500
# Batch saved :  4501
# Batch saved :  4502
# Batch saved :  4503
# Batch saved :  4504
# Batch saved :  4505
# Batch saved :  4506
# Batch saved :  4507
# Batch saved :  4508
# Batch saved :  4509
# Batch saved :  4510
# Batch saved :  4511
# Batch saved :  4512
# Batch saved :  4513
# Batch saved :  4514
# Batch saved :  4515
# Batch saved :  4516
# Batch saved :  4517
# Batch saved :  4518
# Batch saved :  4519
# Batch saved :  4520
# Batch saved :  4521
# Batch saved :  4522
# Batch saved :  4523
# Batch saved :  4524
# Batch saved :  4525
# Batch saved :  4526
# Batch saved :  4527
# Batch saved :  4528
# Batch saved :  4529
# Batch saved :  4530
# Batch saved :  4531
# Batch saved :  4532
# Batch saved :  4533
# Batch saved :  4534
# Batch saved :  4535
# Batch saved :  4536
# Batch saved :  4537
# Batch saved :  4538
# Batch saved :  4539
# Batch saved :  4540
# Batch saved :  4541
# Batch saved :  4542
# Batch saved :  4543
# Batch saved :  4544
# Batch saved :  4545
# Batch saved :  4546
# Batch saved :  4547
# Batch saved :  4548
# Batch saved :  4549
# Batch saved :  4550
# Batch saved :  4551
# Batch saved :  4552
# Batch saved :  4553
# Batch saved :  4554
# Batch saved :  4555
# Batch saved :  4556
# Batch saved :  4557
# Batch saved :  4558
# Batch saved :  4559
# Batch saved :  4560
# Batch saved :  4561
# Batch saved :  4562
# Batch saved :  4563
# Batch saved :  4564
#
# left_data :  (51, 128, 431, 3)
# Batch saved :  4565
# Batch saved :  4566
# Batch saved :  4567
# Batch saved :  4568
# Batch saved :  4569
# Batch saved :  4570
# Batch saved :  4571
# Batch saved :  4572
# Batch saved :  4573
# Batch saved :  4574
# Batch saved :  4575
# Batch saved :  4576
# Batch saved :  4577
# Batch saved :  4578
# Batch saved :  4579
# Batch saved :  4580
# Batch saved :  4581
# Batch saved :  4582
# Batch saved :  4583
# Batch saved :  4584
# Batch saved :  4585
# Batch saved :  4586
# Batch saved :  4587
# Batch saved :  4588
# Batch saved :  4589
# Batch saved :  4590
# Batch saved :  4591
# Batch saved :  4592
# Batch saved :  4593
# Batch saved :  4594
# Batch saved :  4595
# Batch saved :  4596
# Batch saved :  4597
# Batch saved :  4598
# Batch saved :  4599
# Batch saved :  4600
# Batch saved :  4601
# Batch saved :  4602
# Batch saved :  4603
# Batch saved :  4604
# Batch saved :  4605
# Batch saved :  4606
# Batch saved :  4607
# Batch saved :  4608
# Batch saved :  4609
# Batch saved :  4610
# Batch saved :  4611
# Batch saved :  4612
# Batch saved :  4613
# Batch saved :  4614
# Batch saved :  4615
# Batch saved :  4616
# Batch saved :  4617
# Batch saved :  4618
# Batch saved :  4619
# Batch saved :  4620
# Batch saved :  4621
# Batch saved :  4622
# Batch saved :  4623
# Batch saved :  4624
# Batch saved :  4625
# Batch saved :  4626
# Batch saved :  4627
# Batch saved :  4628
# Batch saved :  4629
# Batch saved :  4630
# Batch saved :  4631
# Batch saved :  4632
# Batch saved :  4633
# Batch saved :  4634
# Batch saved :  4635
# Batch saved :  4636
#
# left_data :  (33, 128, 431, 3)
# Batch saved :  4637
# Batch saved :  4638
# Batch saved :  4639
# Batch saved :  4640
# Batch saved :  4641
# Batch saved :  4642
# Batch saved :  4643
# Batch saved :  4644
# Batch saved :  4645
# Batch saved :  4646
# Batch saved :  4647
# Batch saved :  4648
# Batch saved :  4649
# Batch saved :  4650
# Batch saved :  4651
# Batch saved :  4652
# Batch saved :  4653
# Batch saved :  4654
# Batch saved :  4655
# Batch saved :  4656
# Batch saved :  4657
# Batch saved :  4658
# Batch saved :  4659
# Batch saved :  4660
# Batch saved :  4661
# Batch saved :  4662
# Batch saved :  4663
# Batch saved :  4664
# Batch saved :  4665
# Batch saved :  4666
# Batch saved :  4667
# Batch saved :  4668
# Batch saved :  4669
# Batch saved :  4670
# Batch saved :  4671
# Batch saved :  4672
# Batch saved :  4673
# Batch saved :  4674
# Batch saved :  4675
# Batch saved :  4676
# Batch saved :  4677
# Batch saved :  4678
# Batch saved :  4679
# Batch saved :  4680
# Batch saved :  4681
# Batch saved :  4682
# Batch saved :  4683
# Batch saved :  4684
# Batch saved :  4685
# Batch saved :  4686
# Batch saved :  4687
# Batch saved :  4688
# Batch saved :  4689
# Batch saved :  4690
# Batch saved :  4691
# Batch saved :  4692
# Batch saved :  4693
# Batch saved :  4694
# Batch saved :  4695
# Batch saved :  4696
# Batch saved :  4697
# Batch saved :  4698
# Batch saved :  4699
# Batch saved :  4700
# Batch saved :  4701
# Batch saved :  4702
# Batch saved :  4703
# Batch saved :  4704
# Batch saved :  4705
# Batch saved :  4706
# Batch saved :  4707
# Batch saved :  4708
# Batch saved :  4709
# Batch saved :  4710
#
# left_data :  (28, 128, 431, 3)
# Batch saved :  4711
# Batch saved :  4712
# Batch saved :  4713
# Batch saved :  4714
# Batch saved :  4715
# Batch saved :  4716
# Batch saved :  4717
# Batch saved :  4718
# Batch saved :  4719
# Batch saved :  4720
# Batch saved :  4721
# Batch saved :  4722
# Batch saved :  4723
# Batch saved :  4724
# Batch saved :  4725
# Batch saved :  4726
# Batch saved :  4727
# Batch saved :  4728
# Batch saved :  4729
# Batch saved :  4730
# Batch saved :  4731
# Batch saved :  4732
# Batch saved :  4733
# Batch saved :  4734
# Batch saved :  4735
# Batch saved :  4736
# Batch saved :  4737
# Batch saved :  4738
# Batch saved :  4739
# Batch saved :  4740
# Batch saved :  4741
# Batch saved :  4742
# Batch saved :  4743
# Batch saved :  4744
# Batch saved :  4745
# Batch saved :  4746
# Batch saved :  4747
# Batch saved :  4748
# Batch saved :  4749
# Batch saved :  4750
# Batch saved :  4751
# Batch saved :  4752
# Batch saved :  4753
# Batch saved :  4754
# Batch saved :  4755
# Batch saved :  4756
# Batch saved :  4757
# Batch saved :  4758
# Batch saved :  4759
# Batch saved :  4760
# Batch saved :  4761
# Batch saved :  4762
# Batch saved :  4763
# Batch saved :  4764
# Batch saved :  4765
# Batch saved :  4766
# Batch saved :  4767
# Batch saved :  4768
# Batch saved :  4769
# Batch saved :  4770
# Batch saved :  4771
# Batch saved :  4772
# Batch saved :  4773
# Batch saved :  4774
# Batch saved :  4775
# Batch saved :  4776
# Batch saved :  4777
#
# left_data :  (8, 128, 431, 3)
# Batch saved :  4778
# Batch saved :  4779
# Batch saved :  4780
# Batch saved :  4781
# Batch saved :  4782
# Batch saved :  4783
# Batch saved :  4784
# Batch saved :  4785
# Batch saved :  4786
# Batch saved :  4787
# Batch saved :  4788
# Batch saved :  4789
# Batch saved :  4790
# Batch saved :  4791
# Batch saved :  4792
# Batch saved :  4793
# Batch saved :  4794
# Batch saved :  4795
# Batch saved :  4796
# Batch saved :  4797
# Batch saved :  4798
# Batch saved :  4799
# Batch saved :  4800
# Batch saved :  4801
# Batch saved :  4802
# Batch saved :  4803
# Batch saved :  4804
# Batch saved :  4805
# Batch saved :  4806
# Batch saved :  4807
# Batch saved :  4808
# Batch saved :  4809
# Batch saved :  4810
# Batch saved :  4811
# Batch saved :  4812
# Batch saved :  4813
# Batch saved :  4814
# Batch saved :  4815
# Batch saved :  4816
# Batch saved :  4817
# Batch saved :  4818
# Batch saved :  4819
# Batch saved :  4820
# Batch saved :  4821
# Batch saved :  4822
# Batch saved :  4823
# Batch saved :  4824
# Batch saved :  4825
# Batch saved :  4826
# Batch saved :  4827
# Batch saved :  4828
# Batch saved :  4829
# Batch saved :  4830
# Batch saved :  4831
# Batch saved :  4832
# Batch saved :  4833
# Batch saved :  4834
# Batch saved :  4835
# Batch saved :  4836
# Batch saved :  4837
# Batch saved :  4838
# Batch saved :  4839
# Batch saved :  4840
# Batch saved :  4841
#
# left_data :  (21, 128, 431, 3)
# Batch saved :  4842
# Batch saved :  4843
# Batch saved :  4844
# Batch saved :  4845
# Batch saved :  4846
# Batch saved :  4847
# Batch saved :  4848
# Batch saved :  4849
# Batch saved :  4850
# Batch saved :  4851
# Batch saved :  4852
# Batch saved :  4853
# Batch saved :  4854
# Batch saved :  4855
# Batch saved :  4856
# Batch saved :  4857
# Batch saved :  4858
# Batch saved :  4859
# Batch saved :  4860
# Batch saved :  4861
# Batch saved :  4862
# Batch saved :  4863
# Batch saved :  4864
# Batch saved :  4865
# Batch saved :  4866
# Batch saved :  4867
# Batch saved :  4868
# Batch saved :  4869
# Batch saved :  4870
# Batch saved :  4871
# Batch saved :  4872
# Batch saved :  4873
# Batch saved :  4874
# Batch saved :  4875
# Batch saved :  4876
# Batch saved :  4877
# Batch saved :  4878
# Batch saved :  4879
# Batch saved :  4880
# Batch saved :  4881
# Batch saved :  4882
# Batch saved :  4883
# Batch saved :  4884
# Batch saved :  4885
# Batch saved :  4886
# Batch saved :  4887
# Batch saved :  4888
# Batch saved :  4889
# Batch saved :  4890
# Batch saved :  4891
# Batch saved :  4892
# Batch saved :  4893
# Batch saved :  4894
# Batch saved :  4895
# Batch saved :  4896
# Batch saved :  4897
# Batch saved :  4898
# Batch saved :  4899
# Batch saved :  4900
# Batch saved :  4901
# Batch saved :  4902
# Batch saved :  4903
#
# left_data :  (19, 128, 431, 3)
# Batch saved :  4904
# Batch saved :  4905
# Batch saved :  4906
# Batch saved :  4907
# Batch saved :  4908
# Batch saved :  4909
# Batch saved :  4910
# Batch saved :  4911
# Batch saved :  4912
# Batch saved :  4913
# Batch saved :  4914
# Batch saved :  4915
# Batch saved :  4916
# Batch saved :  4917
# Batch saved :  4918
# Batch saved :  4919
# Batch saved :  4920
# Batch saved :  4921
# Batch saved :  4922
# Batch saved :  4923
# Batch saved :  4924
# Batch saved :  4925
# Batch saved :  4926
# Batch saved :  4927
# Batch saved :  4928
# Batch saved :  4929
# Batch saved :  4930
# Batch saved :  4931
# Batch saved :  4932
# Batch saved :  4933
# Batch saved :  4934
# Batch saved :  4935
# Batch saved :  4936
# Batch saved :  4937
# Batch saved :  4938
# Batch saved :  4939
# Batch saved :  4940
# Batch saved :  4941
# Batch saved :  4942
# Batch saved :  4943
# Batch saved :  4944
# Batch saved :  4945
# Batch saved :  4946
# Batch saved :  4947
# Batch saved :  4948
# Batch saved :  4949
# Batch saved :  4950
# Batch saved :  4951
# Batch saved :  4952
# Batch saved :  4953
# Batch saved :  4954
# Batch saved :  4955
# Batch saved :  4956
# Batch saved :  4957
# Batch saved :  4958
# Batch saved :  4959
# Batch saved :  4960
# Batch saved :  4961
# Batch saved :  4962
# Batch saved :  4963
# Batch saved :  4964
# Batch saved :  4965
# Batch saved :  4966
# Batch saved :  4967
# Batch saved :  4968
# Batch saved :  4969
# Batch saved :  4970
#
# left_data :  (45, 128, 431, 3)
# Batch saved :  4971
# Batch saved :  4972
# Batch saved :  4973
# Batch saved :  4974
# Batch saved :  4975
# Batch saved :  4976
# Batch saved :  4977
# Batch saved :  4978
# Batch saved :  4979
# Batch saved :  4980
# Batch saved :  4981
# Batch saved :  4982
# Batch saved :  4983
# Batch saved :  4984
# Batch saved :  4985
# Batch saved :  4986
# Batch saved :  4987
# Batch saved :  4988
# Batch saved :  4989
# Batch saved :  4990
# Batch saved :  4991
# Batch saved :  4992
# Batch saved :  4993
# Batch saved :  4994
# Batch saved :  4995
# Batch saved :  4996
# Batch saved :  4997
# Batch saved :  4998
# Batch saved :  4999
# Batch saved :  5000
# Batch saved :  5001
# Batch saved :  5002
# Batch saved :  5003
# Batch saved :  5004
# Batch saved :  5005
# Batch saved :  5006
# Batch saved :  5007
# Batch saved :  5008
# Batch saved :  5009
# Batch saved :  5010
#
# left_data :  (57, 128, 431, 3)
# Batch saved :  5011
# Batch saved :  5012
# Batch saved :  5013
# Batch saved :  5014
# Batch saved :  5015
# Batch saved :  5016
# Batch saved :  5017
# Batch saved :  5018
# Batch saved :  5019
# Batch saved :  5020
# Batch saved :  5021
# Batch saved :  5022
# Batch saved :  5023
# Batch saved :  5024
# Batch saved :  5025
# Batch saved :  5026
# Batch saved :  5027
# Batch saved :  5028
# Batch saved :  5029
# Batch saved :  5030
# Batch saved :  5031
# Batch saved :  5032
# Batch saved :  5033
# Batch saved :  5034
# Batch saved :  5035
# Batch saved :  5036
# Batch saved :  5037
# Batch saved :  5038
# Batch saved :  5039
# Batch saved :  5040
# Batch saved :  5041
# Batch saved :  5042
# Batch saved :  5043
# Batch saved :  5044
# Batch saved :  5045
# Batch saved :  5046
# Batch saved :  5047
# Batch saved :  5048
# Batch saved :  5049
# Batch saved :  5050
# Batch saved :  5051
# Batch saved :  5052
# Batch saved :  5053
# Batch saved :  5054
# Batch saved :  5055
# Batch saved :  5056
# Batch saved :  5057
# Batch saved :  5058
# Batch saved :  5059
# Batch saved :  5060
# Batch saved :  5061
# Batch saved :  5062
# Batch saved :  5063
# Batch saved :  5064
# Batch saved :  5065
# Batch saved :  5066
# Batch saved :  5067
# Batch saved :  5068
# Batch saved :  5069
# Batch saved :  5070
# Batch saved :  5071
# Batch saved :  5072
# Batch saved :  5073
# Batch saved :  5074
# Batch saved :  5075
# Batch saved :  5076
# Batch saved :  5077
# Batch saved :  5078
# Batch saved :  5079
# Batch saved :  5080
# Batch saved :  5081
# Batch saved :  5082
# Batch saved :  5083
# Batch saved :  5084
# Batch saved :  5085
# Batch saved :  5086
# Batch saved :  5087
# Batch saved :  5088
# Batch saved :  5089
# Batch saved :  5090
# Batch saved :  5091
# Batch saved :  5092
# Batch saved :  5093
#
# left_data :  (12, 128, 431, 3)

# %%
# Last Batch of 12 is not taken
